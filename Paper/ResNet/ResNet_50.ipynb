# %% [markdown]
# > Convolution layer의 feature map의 크기를 줄일 때, pooling보다는 stride=2를 이용!
#
# > F(x)+x할 때 서로의 차원의 크기가 맞지 않으면, 1x1 conv를 통해서 feature map의 갯수를 맞추자

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Dense, Activation, add, Flatten, GlobalAveragePooling2D, Reshape, multiply
from keras.models import Model

import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator


width = 32
height = 32

# cifar data download
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
num_classes = 10
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
val_images, val_labels = x_train[:500], y_train[:500]
train_images, train_labels = x_train[500:], y_train[500:]

# %% [markdown]
# ### concat을 진행하는게 아니라 add를 진행하는 이유?
# element by elemet 값을 더해주는 것이기 때문이다.

# %%
def Residual_Block(x, filter):

    x_skip = x 
    f= filter

    x = Conv2D(f, kernel_size=(3,3), strides=1, padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(f, kernel_size=(3,3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # projection 진행
    x_skip = Conv2D(f, kernel_size=(1,1),strides=(1,1),padding='same')(x_skip) #1x1 conv을 f만큼 진행해서 projection을 한다.
    x_skip = BatchNormalization()(x_skip)    

    x = add([x, x_skip]) # concat을 처음에 진행했는데 조금 다른 값이 나온거 같다. why?
    x = Activation('relu')(x)    
    
    return x

# %%
def Residual_Block_50(x, filters):
    f1, f2 = filters
    x_skip = x # 초기의 x

    x = Conv2D(f1, kernel_size=(1,1), strides=1, padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(f1, kernel_size=(3,3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(f2, kernel_size=(1,1), strides=1, padding='same')(x) 
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    #scale
    x_skip = Conv2D(f2, kernel_size=(1,1),strides=(1,1),padding='same')(x_skip)
    x_skip = BatchNormalization()(x_skip)    

    #skip connection
    x = add([x, x_skip])
    x = Activation('relu')(x)    
    
    return x

# %%
inputs = Input(shape=(32,32,3))
x = Conv2D(64, kernel_size=7, strides=2, padding='valid')(inputs)
x = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(x)

for i in range(3):
  x = Residual_Block_50(x, filters=(64,256)) 

for i in range(4):
  x = Residual_Block_50(x, filters =(128,512)) 

for i in range(6):
  x = Residual_Block_50(x, filters =(256,1024)) 

for i in range(3):
  x = Residual_Block_50(x, filters =(512,2048)) 

x = GlobalAveragePooling2D()(x) 

outputs = Dense(10, activation = 'softmax')(x)
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 13, 13, 64)   9472        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 7, 7, 64)     0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     4160        ['max_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 7, 64)    256         ['conv2d_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 7, 7, 64)     0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 64)     36928       ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 256)    16640       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 7, 7, 256)    16640       ['max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 7, 7, 256)    0           ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 7, 7, 256)    0           ['activation_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 256)    0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 64)     16448       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 64)     36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 256)    16640       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 256)    65792       ['activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 7, 7, 256)    0           ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 7, 7, 256)    0           ['activation_6[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_7 (Activation)      (None, 7, 7, 256)    0           ['add_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 64)     16448       ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 64)     36928       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 64)    256         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 7, 7, 64)     0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 256)    16640       ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  conv2d_12 (Conv2D)             (None, 7, 7, 256)    65792       ['activation_7[0][0]']
#
#  activation_10 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 7, 7, 256)    0           ['activation_10[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  activation_11 (Activation)     (None, 7, 7, 256)    0           ['add_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 7, 7, 128)    32896       ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 7, 7, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 7, 7, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 7, 7, 512)    66048       ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 512)    131584      ['activation_11[0][0]']
#
#  activation_14 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 7, 7, 512)    0           ['activation_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_15 (Activation)     (None, 7, 7, 512)    0           ['add_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 128)    65664       ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 512)    66048       ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_19[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 512)    262656      ['activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_20[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 7, 7, 512)    0           ['activation_18[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  activation_19 (Activation)     (None, 7, 7, 512)    0           ['add_4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 128)    65664       ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 7, 7, 128)   512         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 7, 7, 128)   512         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 512)    66048       ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 7, 7, 512)    262656      ['activation_19[0][0]']
#
#  activation_22 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_24[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 7, 7, 512)    0           ['activation_22[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  activation_23 (Activation)     (None, 7, 7, 512)    0           ['add_5[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 7, 7, 128)    65664       ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 7, 7, 128)   512         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 7, 7, 128)    147584      ['activation_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 7, 7, 128)   512         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 512)    66048       ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_27[0][0]']
#  ormalization)
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 512)    262656      ['activation_23[0][0]']
#
#  activation_26 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 7, 7, 512)    0           ['activation_26[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  activation_27 (Activation)     (None, 7, 7, 512)    0           ['add_6[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 256)    131328      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_31[0][0]']
#  ormalization)
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 1024)   525312      ['activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 7, 7, 1024)   0           ['activation_30[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  activation_31 (Activation)     (None, 7, 7, 1024)   0           ['add_7[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_35[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 1024)   1049600     ['activation_31[0][0]']
#
#  activation_34 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 7, 7, 1024)   0           ['activation_34[0][0]',
#                                                                   'batch_normalization_35[0][0]']
#
#  activation_35 (Activation)     (None, 7, 7, 1024)   0           ['add_8[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_39[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 1024)   1049600     ['activation_35[0][0]']
#
#  activation_38 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_40[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 7, 7, 1024)   0           ['activation_38[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  activation_39 (Activation)     (None, 7, 7, 1024)   0           ['add_9[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_43[0][0]']
#  ormalization)
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 1024)   1049600     ['activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_44[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 7, 7, 1024)   0           ['activation_42[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  activation_43 (Activation)     (None, 7, 7, 1024)   0           ['add_10[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 1024)   1049600     ['activation_43[0][0]']
#
#  activation_46 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_48[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['activation_46[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  activation_47 (Activation)     (None, 7, 7, 1024)   0           ['add_11[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 256)    262400      ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 1024)   263168      ['activation_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_51[0][0]']
#  ormalization)
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 1024)   1049600     ['activation_47[0][0]']
#
#  activation_50 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_52[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 1024)   0           ['activation_50[0][0]',
#                                                                   'batch_normalization_51[0][0]']
#
#  activation_51 (Activation)     (None, 7, 7, 1024)   0           ['add_12[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_55[0][0]']
#  ormalization)
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 7, 7, 2048)   0           ['batch_normalization_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['activation_54[0][0]',
#                                                                   'batch_normalization_55[0][0]']
#
#  activation_55 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_59[0][0]']
#  ormalization)
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 2048)   4196352     ['activation_55[0][0]']
#
#  activation_58 (Activation)     (None, 7, 7, 2048)   0           ['batch_normalization_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_60[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['activation_58[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  activation_59 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_63[0][0]']
#  ormalization)
#
#  conv2d_64 (Conv2D)             (None, 7, 7, 2048)   4196352     ['activation_59[0][0]']
#
#  activation_62 (Activation)     (None, 7, 7, 2048)   0           ['batch_normalization_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_64[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['activation_62[0][0]',
#                                                                   'batch_normalization_63[0][0]']
#
#  activation_63 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['activation_63[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           20490       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 38,213,258
# Trainable params: 38,137,738
# Non-trainable params: 75,520
# __________________________________________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagenerator = ImageDataGenerator(rescale = 1./255, shear_range = 0.2,
                                   zoom_range = 0.2, horizontal_flip = True)
validation_datagenerator = ImageDataGenerator(rescale = 1./255, shear_range = 0.2,
                                   zoom_range = 0.2, horizontal_flip = True)

# %%
history = model.fit(train_datagenerator.flow(train_images,train_labels, batch_size = 32), 
                    validation_data = validation_datagenerator.flow(val_images, val_labels, batch_size = 32),
                    epochs = 10)
# Out:
# Epoch 1/10
# 1547/1547 [==============================] - 234s 140ms/step - loss: 1.9411 - accuracy: 0.2984 - val_loss: 1.6912 - val_accuracy: 0.3740
# Epoch 2/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 1.5513 - accuracy: 0.4356 - val_loss: 1.4767 - val_accuracy: 0.4840
# Epoch 3/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 1.3949 - accuracy: 0.4957 - val_loss: 1.4469 - val_accuracy: 0.4900
# Epoch 4/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 1.2768 - accuracy: 0.5453 - val_loss: 1.4827 - val_accuracy: 0.4540
# Epoch 5/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 1.1777 - accuracy: 0.5830 - val_loss: 1.1616 - val_accuracy: 0.5980
# Epoch 6/10
# 1547/1547 [==============================] - 213s 138ms/step - loss: 1.0894 - accuracy: 0.6162 - val_loss: 1.0607 - val_accuracy: 0.6200
# Epoch 7/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 1.0146 - accuracy: 0.6448 - val_loss: 1.0858 - val_accuracy: 0.6340
# Epoch 8/10
# 1547/1547 [==============================] - 214s 138ms/step - loss: 0.9485 - accuracy: 0.6685 - val_loss: 1.0744 - val_accuracy: 0.6000
# Epoch 9/10
# 1547/1547 [==============================] - 213s 138ms/step - loss: 0.8880 - accuracy: 0.6868 - val_loss: 0.9424 - val_accuracy: 0.6980
# Epoch 10/10
# 1547/1547 [==============================] - 213s 138ms/step - loss: 0.8367 - accuracy: 0.7087 - val_loss: 1.2343 - val_accuracy: 0.6140

# %% [markdown]
# BasicBlock (ResNet18, ResNet34)이랑 Bottleneck (ResNet50, ResNet101, ResNet152)
#
# ```
# # for i in range(3):
#   x = Residual_Block_50(x, filters=(64,256))
#
# for i in range(4):
#   x = Residual_Block_50(x, filters =(128,512))
#
# for i in range(6):
#   x = Residual_Block_50(x, filters =(256,1024))
#
# for i in range(3):
#   x = Residual_Block_50(x, filters =(512,2048))
# ```
# ResNet-50으로 정의된 내용을 위의 내용으로 대체해서 쓰면 basic으로 바뀐다.

# %%
x = Residual_Block(x, filter = 64)
x = Residual_Block(x, filter = 64)

x = Residual_Block(x, filter = 128)
x = Residual_Block(x, filter = 128)

x = Residual_Block(x, filter = 256)
x = Residual_Block(x, filter = 256)

x = Residual_Block(x, filter = 512)
x = Residual_Block(x, filter = 512)
