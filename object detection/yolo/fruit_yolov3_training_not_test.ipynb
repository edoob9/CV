# %%
import os, sys

# %% [markdown]
# config

# %%
# YOLO options
YOLO_DARKNET_WEIGHTS        = "./model_data/yolov3.weights"
YOLO_COCO_CLASSES           = "./model_data/coco.names"
YOLO_STRIDES                = [8, 16, 32]
YOLO_IOU_LOSS_THRESH        = 0.5
YOLO_ANCHOR_PER_SCALE       = 3
YOLO_MAX_BBOX_PER_SCALE     = 100
YOLO_INPUT_SIZE             = 416
YOLO_ANCHORS                = [[[10,  13], [16,   30], [33,   23]],
                               [[30,  61], [62,   45], [59,  119]],
                               [[116, 90], [156, 198], [373, 326]]]
# Train options
TRAIN_CLASSES               = "./model_data/fruits.names"
TRAIN_ANNOT_PATH            = "./fruits_data/fruits_train.txt"
TRAIN_BATCH_SIZE            = 4
TRAIN_INPUT_SIZE            = 416
TRAIN_DATA_AUG              = True
TRAIN_TRANSFER              = False # why? True를 하지않을까 -> GIOU발산하는 경우가 낮아진다. 단, 시간이 x
TRAIN_FROM_CHECKPOINT       = False #"./checkpoints/yolov3_custom"

TRAIN_LR_INIT               = 1e-4
TRAIN_LR_END                = 1e-7
TRAIN_WARMUP_EPOCHS         = 2
TRAIN_EPOCHS                = 11 
''' 계속 giou_val_loss: Nan , total_val_loss: Nan -> 발생하기 때문에 
TRAIN_LR_INIT               = 값 -> 수치값을 변화시킨다
TRAIN_LR_END                = 값
TRAIN_WARMUP_EPOCHS         = 값
'''

# TEST options
TEST_ANNOT_PATH             = "./fruits_data/fruits_test.txt"
TEST_BATCH_SIZE             = 4
TEST_INPUT_SIZE             = 416
TEST_DATA_AUG               = False

# %%
import cv2
import time
import random
import colorsys
import numpy as np
import tensorflow as tf

# %% [markdown]
# utils

# %%
def load_yolo_weights(model, weights_file):
    tf.keras.backend.clear_session() # used to reset layer names
    # load Darknet original weights to Keras model
    with open(weights_file, 'rb') as wf:
        major, minor, revision, seen, _ = np.fromfile(wf, dtype=np.int32, count=5)

        j = 0
        for i in range(75):
            if i > 0:
                conv_layer_name = 'conv2d_%d' %i
            else:
                conv_layer_name = 'conv2d'
                
            if j > 0:
                bn_layer_name = 'batch_normalization_%d' %j
            else:
                bn_layer_name = 'batch_normalization'
            
            conv_layer = model.get_layer(conv_layer_name)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]

            if i not in [58, 66, 74]:
                # darknet weights: [beta, gamma, mean, variance]
                bn_weights = np.fromfile(wf, dtype=np.float32, count=4 * filters)
                # tf weights: [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
                bn_layer = model.get_layer(bn_layer_name)
                j += 1
            else:
                conv_bias = np.fromfile(wf, dtype=np.float32, count=filters)

            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(wf, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(conv_shape).transpose([2, 3, 1, 0])

            if i not in [58, 66, 74]:
                conv_layer.set_weights([conv_weights])
                bn_layer.set_weights(bn_weights)
            else:
                conv_layer.set_weights([conv_weights, conv_bias])

# %%
def read_class_names(class_file_name):
    # loads class name from a file
    #print(class_file_name)
    names = {}
    with open(class_file_name, 'r') as data:
        for ID, name in enumerate(data):
            names[ID] = name.strip('\n')
    return names

# %%
def image_preprocess(image, target_size, gt_boxes=None):
    ih, iw    = target_size
    h,  w, _  = image.shape

    scale = min(iw/w, ih/h)
    nw, nh  = int(scale * w), int(scale * h)
    image_resized = cv2.resize(image, (nw, nh))

    image_paded = np.full(shape=[ih, iw, 3], fill_value=128.0)
    dw, dh = (iw - nw) // 2, (ih-nh) // 2
    image_paded[dh:nh+dh, dw:nw+dw, :] = image_resized
    image_paded = image_paded / 255.

    if gt_boxes is None:
        return image_paded

    else:
        gt_boxes[:, [0, 2]] = gt_boxes[:, [0, 2]] * scale + dw
        gt_boxes[:, [1, 3]] = gt_boxes[:, [1, 3]] * scale + dh
        return image_paded, gt_boxes

# %%
def draw_bbox(image, bboxes, CLASSES=YOLO_COCO_CLASSES, show_label=True, show_confidence = True, Text_colors=(255,255,0), rectangle_colors=''):   
    NUM_CLASS = read_class_names(CLASSES)
    num_classes = len(NUM_CLASS)
    image_h, image_w, _ = image.shape
    hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
    #print("hsv_tuples", hsv_tuples)
    colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
    colors = list(map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), colors))

    random.seed(0)
    random.shuffle(colors)
    random.seed(None)

    for i, bbox in enumerate(bboxes):
        coor = np.array(bbox[:4], dtype=np.int32)
        score = bbox[4]
        class_ind = int(bbox[5])
        bbox_color = rectangle_colors if rectangle_colors != ''else colors[class_ind]
        bbox_thick = int(0.6 * (image_h + image_w) / 1000)
        if bbox_thick < 1: bbox_thick = 1
        #print(image_h, image_w, bbox_thick)
        fontScale = 0.75 * bbox_thick
        (x1, y1), (x2, y2) = (coor[0], coor[1]), (coor[2], coor[3])

        # put object rectangle
        cv2.rectangle(image, (x1, y1), (x2, y2), bbox_color, bbox_thick*2)

        if show_label:
            # get text label
            score_str = f' {score:.2f}' if show_confidence else '' 
            label = f'{NUM_CLASS[class_ind]}' + score_str

            # get text size
            (text_width, text_height), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_COMPLEX_SMALL,
                                                                  fontScale, thickness=bbox_thick)
            # put filled text rectangle
            cv2.rectangle(image, (x1, y1), (x1 + text_width, y1 - text_height - baseline), bbox_color, thickness=cv2.FILLED)

            # put text above rectangle
            cv2.putText(image, label, (x1, y1-4), cv2.FONT_HERSHEY_COMPLEX_SMALL,
                        fontScale, Text_colors, bbox_thick, lineType=cv2.LINE_AA)

                        

    return image

# %% [markdown]
# Already define IOU, NMS function

# %%
def postprocess_boxes(pred_bbox, original_image, input_size, score_threshold):
    valid_scale=[0, np.inf]
    pred_bbox = np.array(pred_bbox)

    pred_xywh = pred_bbox[:, 0:4]
    pred_conf = pred_bbox[:, 4]
    pred_prob = pred_bbox[:, 5:]

    # 1. (x, y, w, h) --> (xmin, ymin, xmax, ymax)
    pred_coor = np.concatenate([pred_xywh[:, :2] - pred_xywh[:, 2:] * 0.5,
                                pred_xywh[:, :2] + pred_xywh[:, 2:] * 0.5], axis=-1)
    # 2. (xmin, ymin, xmax, ymax) -> (xmin_org, ymin_org, xmax_org, ymax_org)
    org_h, org_w = original_image.shape[:2]
    resize_ratio = min(input_size / org_w, input_size / org_h)

    dw = (input_size - resize_ratio * org_w) / 2
    dh = (input_size - resize_ratio * org_h) / 2

    pred_coor[:, 0::2] = 1.0 * (pred_coor[:, 0::2] - dw) / resize_ratio
    pred_coor[:, 1::2] = 1.0 * (pred_coor[:, 1::2] - dh) / resize_ratio

    # 3. clip some boxes those are out of range
    pred_coor = np.concatenate([np.maximum(pred_coor[:, :2], [0, 0]),
                                np.minimum(pred_coor[:, 2:], [org_w - 1, org_h - 1])], axis=-1)
    invalid_mask = np.logical_or((pred_coor[:, 0] > pred_coor[:, 2]), (pred_coor[:, 1] > pred_coor[:, 3]))
    pred_coor[invalid_mask] = 0

    # 4. discard some invalid boxes
    bboxes_scale = np.sqrt(np.multiply.reduce(pred_coor[:, 2:4] - pred_coor[:, 0:2], axis=-1))
    scale_mask = np.logical_and((valid_scale[0] < bboxes_scale), (bboxes_scale < valid_scale[1]))

    # 5. discard boxes with low scores
    classes = np.argmax(pred_prob, axis=-1)
    scores = pred_conf * pred_prob[np.arange(len(pred_coor)), classes]
    score_mask = scores > score_threshold
    mask = np.logical_and(scale_mask, score_mask)
    coors, scores, classes = pred_coor[mask], scores[mask], classes[mask]
    #print(coors)

    #print(coors[0])
    return np.concatenate([coors, scores[:, np.newaxis], classes[:, np.newaxis]], axis=-1)

# %%
def detect_image(YoloV3, image_path, output_path, input_size=416, show=False, CLASSES=YOLO_COCO_CLASSES, score_threshold=0.3, iou_threshold=0.45, rectangle_colors=''):
    original_image      = cv2.imread(image_path)

    original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    image_data = image_preprocess(np.copy(original_image), [input_size, input_size])
    image_data = tf.expand_dims(image_data, 0)

    pred_bbox = YoloV3.predict(image_data)
    pred_bbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_bbox]
    pred_bbox = tf.concat(pred_bbox, axis=0)
    
    bboxes = postprocess_boxes(pred_bbox, original_image, input_size, score_threshold)
    #xx=np.array(bboxes)
    #print(xx.shape)

    bboxes = nms(bboxes, iou_threshold)
    image = draw_bbox(original_image, bboxes, CLASSES=CLASSES, rectangle_colors=rectangle_colors)
    #cv2.imwrite('./output.jpg의 사본', image)
        
    return image

# %% [markdown]
# model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, ZeroPadding2D, BatchNormalization
from tensorflow.keras.regularizers import l2



STRIDES         = np.array(YOLO_STRIDES)
ANCHORS         = (np.array(YOLO_ANCHORS).T/STRIDES).T
IOU_LOSS_THRESH = YOLO_IOU_LOSS_THRESH

# %%
class BatchNormalization(BatchNormalization):
    # "Frozen state" and "inference mode" are two separate concepts.
    # `layer.trainable = False` is to freeze the layer, so the layer will use
    # stored moving `var` and `mean` in the "inference mode", and both `gama`
    # and `beta` will not be updated !
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

#training :False inference => moving mean, True training = > mean
#trainable : False (frozen), Ture (Not frozen)

def convolutional(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides,
                  padding=padding, use_bias=not bn, kernel_regularizer=l2(0.0005),
                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                  bias_initializer=tf.constant_initializer(0.))(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate == True:
        conv = LeakyReLU(alpha=0.1)(conv)

    return conv

def residual_block(input_layer, input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    residual_output = short_cut + conv
    return residual_output

def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')


def darknet53(input_data):
    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 512, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 1024, 512, 1024)

    return route_1, route_2, input_data

def YOLOv3(input_layer, NUM_CLASS):
    # After the input layer enters the Darknet-53 network, we get three branches
    route_1, route_2, conv = darknet53(input_layer)
    # See the orange module (DBL) in the figure above, a total of 5 Subconvolution operation
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv = convolutional(conv, (3, 3,  512, 1024))
    conv = convolutional(conv, (1, 1, 1024,  512))
    conv_lobj_branch = convolutional(conv, (3, 3, 512, 1024))
    
    # conv_lbbox is used to predict large-sized objects , Shape = [None, 13, 13, 255] 
    conv_lbbox = convolutional(conv_lobj_branch, (1, 1, 1024, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1,  512,  256))
    # upsample here uses the nearest neighbor interpolation method, which has the advantage that the
    # upsampling process does not need to learn, thereby reducing the network parameter  
    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)
    conv = convolutional(conv, (1, 1, 768, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv = convolutional(conv, (3, 3, 256, 512))
    conv = convolutional(conv, (1, 1, 512, 256))
    conv_mobj_branch = convolutional(conv, (3, 3, 256, 512))

    # conv_mbbox is used to predict medium-sized objects, shape = [None, 26, 26, 255]
    conv_mbbox = convolutional(conv_mobj_branch, (1, 1, 512, 3*(NUM_CLASS + 5)), activate=False, bn=False)

    conv = convolutional(conv, (1, 1, 256, 128))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)
    conv = convolutional(conv, (1, 1, 384, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv = convolutional(conv, (3, 3, 128, 256))
    conv = convolutional(conv, (1, 1, 256, 128))
    conv_sobj_branch = convolutional(conv, (3, 3, 128, 256))
    
    # conv_sbbox is used to predict small size objects, shape = [None, 52, 52, 255]
    conv_sbbox = convolutional(conv_sobj_branch, (1, 1, 256, 3*(NUM_CLASS +5)), activate=False, bn=False)
        
    return [conv_sbbox, conv_mbbox, conv_lbbox]

def Create_Yolov3(input_size=416, channels=3, training=False, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES))
    input_layer  = Input([input_size, input_size, channels])

    conv_tensors = YOLOv3(input_layer, NUM_CLASS)

    output_tensors = []
    for i, conv_tensor in enumerate(conv_tensors):
        pred_tensor = decode(conv_tensor, NUM_CLASS, i)
        if training: output_tensors.append(conv_tensor)
        output_tensors.append(pred_tensor)

    YoloV3 = tf.keras.Model(input_layer, output_tensors)
    return YoloV3

def decode(conv_output, NUM_CLASS, i=0):
    # where i = 0, 1 or 2 to correspond to the three grid scales  
    conv_shape       = tf.shape(conv_output)
    batch_size       = conv_shape[0]
    output_size      = conv_shape[1]

    conv_output = tf.reshape(conv_output, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_dxdy = conv_output[:, :, :, :, 0:2] # offset of center position     
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4] # Prediction box length and width offset
    conv_raw_conf = conv_output[:, :, :, :, 4:5] # confidence of the prediction box
    conv_raw_prob = conv_output[:, :, :, :, 5: ] # category probability of the prediction box 

    # next need Draw the grid. Where output_size is equal to 13, 26 or 52  
    y = tf.range(output_size, dtype=tf.int32)
    y = tf.expand_dims(y, -1)
    y = tf.tile(y, [1, output_size])
    x = tf.range(output_size,dtype=tf.int32)
    x = tf.expand_dims(x, 0)
    x = tf.tile(x, [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis], y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :], [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    # Calculate the center position of the prediction box:
    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]
    # Calculate the length and width of the prediction box:
    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]

    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)
    pred_conf = tf.sigmoid(conv_raw_conf) # object box calculates the predicted confidence
    pred_prob = tf.sigmoid(conv_raw_prob) # calculating the predicted probability category box object

    # calculating the predicted probability category box object
    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

def bbox_iou(boxes1, boxes2):
    boxes1_area = boxes1[..., 2] * boxes1[..., 3]
    boxes2_area = boxes2[..., 2] * boxes2[..., 3]

    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area

    return 1.0 * inter_area / union_area

def bbox_giou(boxes1, boxes2):
    boxes1 = tf.concat([boxes1[..., :2] - boxes1[..., 2:] * 0.5,
                        boxes1[..., :2] + boxes1[..., 2:] * 0.5], axis=-1)
    boxes2 = tf.concat([boxes2[..., :2] - boxes2[..., 2:] * 0.5,
                        boxes2[..., :2] + boxes2[..., 2:] * 0.5], axis=-1)

    boxes1 = tf.concat([tf.minimum(boxes1[..., :2], boxes1[..., 2:]),
                        tf.maximum(boxes1[..., :2], boxes1[..., 2:])], axis=-1)
    boxes2 = tf.concat([tf.minimum(boxes2[..., :2], boxes2[..., 2:]),
                        tf.maximum(boxes2[..., :2], boxes2[..., 2:])], axis=-1)

    boxes1_area = (boxes1[..., 2] - boxes1[..., 0]) * (boxes1[..., 3] - boxes1[..., 1])
    boxes2_area = (boxes2[..., 2] - boxes2[..., 0]) * (boxes2[..., 3] - boxes2[..., 1])

    left_up = tf.maximum(boxes1[..., :2], boxes2[..., :2])
    right_down = tf.minimum(boxes1[..., 2:], boxes2[..., 2:])

    inter_section = tf.maximum(right_down - left_up, 0.0)
    inter_area = inter_section[..., 0] * inter_section[..., 1]
    union_area = boxes1_area + boxes2_area - inter_area
    iou = inter_area / union_area

    enclose_left_up = tf.minimum(boxes1[..., :2], boxes2[..., :2])
    enclose_right_down = tf.maximum(boxes1[..., 2:], boxes2[..., 2:])
    enclose = tf.maximum(enclose_right_down - enclose_left_up, 0.0)
    enclose_area = enclose[..., 0] * enclose[..., 1]
    giou = iou - 1.0 * (enclose_area - union_area) / enclose_area

    return giou


def compute_loss(pred, conv, label, bboxes, i=0, CLASSES=YOLO_COCO_CLASSES):
    NUM_CLASS = len(read_class_names(CLASSES)) # 클래스 3개
    conv_shape  = tf.shape(conv)
    batch_size  = conv_shape[0]
    output_size = conv_shape[1]
    input_size  = STRIDES[i] * output_size
    conv = tf.reshape(conv, (batch_size, output_size, output_size, 3, 5 + NUM_CLASS))

    conv_raw_conf = conv[:, :, :, :, 4:5]
    conv_raw_prob = conv[:, :, :, :, 5:]

    pred_xywh     = pred[:, :, :, :, 0:4]
    pred_conf     = pred[:, :, :, :, 4:5]

    label_xywh    = label[:, :, :, :, 0:4]
    respond_bbox  = label[:, :, :, :, 4:5]
    label_prob    = label[:, :, :, :, 5:]

    giou = tf.expand_dims(bbox_giou(pred_xywh, label_xywh), axis=-1)
    input_size = tf.cast(input_size, tf.float32)

    #https://giou.stanford.edu/GIoU.pdf
    bbox_loss_scale = 2.0 - 1.0 * label_xywh[:, :, :, :, 2:3] * label_xywh[:, :, :, :, 3:4] / (input_size ** 2)
    giou_loss = respond_bbox * bbox_loss_scale * (1- giou)

    iou = bbox_iou(pred_xywh[:, :, :, :, np.newaxis, :], bboxes[:, np.newaxis, np.newaxis, np.newaxis, :, :])
    max_iou = tf.expand_dims(tf.reduce_max(iou, axis=-1), axis=-1)

    # respond_bbox 1인경우, bgd = 0 ; rbbox가 0인동시에 max iou < 0.5인경우 bgd = 1
    respond_bgd = (1.0 - respond_bbox) * tf.cast( max_iou < IOU_LOSS_THRESH, tf.float32 )

    conf_focal = tf.pow(respond_bbox - pred_conf, 2)

    conf_loss = conf_focal * (
            respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
            +
            respond_bgd * tf.nn.sigmoid_cross_entropy_with_logits(labels=respond_bbox, logits=conv_raw_conf)
    )

    prob_loss = respond_bbox * tf.nn.sigmoid_cross_entropy_with_logits(labels=label_prob, logits=conv_raw_prob)

    giou_loss = tf.reduce_mean(tf.reduce_sum(giou_loss, axis=[1,2,3,4]))
    conf_loss = tf.reduce_mean(tf.reduce_sum(conf_loss, axis=[1,2,3,4]))
    prob_loss = tf.reduce_mean(tf.reduce_sum(prob_loss, axis=[1,2,3,4]))

    return giou_loss, conf_loss, prob_loss

# %% [markdown]
# dataset

# %%
import os
import cv2
import random
import numpy as np
import tensorflow as tf



class Dataset(object):
    # Dataset preprocess implementation
    def __init__(self, dataset_type):
        self.annot_path  = TRAIN_ANNOT_PATH if dataset_type == 'train' else TEST_ANNOT_PATH
        self.input_sizes = TRAIN_INPUT_SIZE if dataset_type == 'train' else TEST_INPUT_SIZE
        self.batch_size  = TRAIN_BATCH_SIZE if dataset_type == 'train' else TEST_BATCH_SIZE
        self.data_aug    = TRAIN_DATA_AUG   if dataset_type == 'train' else TEST_DATA_AUG

        self.train_input_sizes = TRAIN_INPUT_SIZE # 416
        self.strides = np.array(YOLO_STRIDES)
        self.classes = read_class_names(TRAIN_CLASSES)
        self.num_classes = len(self.classes)
        self.anchors = (np.array(YOLO_ANCHORS).T/self.strides).T
        self.anchor_per_scale = YOLO_ANCHOR_PER_SCALE
        self.max_bbox_per_scale = YOLO_MAX_BBOX_PER_SCALE

        self.annotations = self.load_annotations(dataset_type)
        self.num_samples = len(self.annotations)
        self.num_batchs = int(np.ceil(self.num_samples / self.batch_size))
        self.batch_count = 0


    def load_annotations(self, dataset_type):
        final_annotations = []
        with open(self.annot_path, 'r') as f:
            txt = f.readlines()
            annotations = [line.strip() for line in txt if len(line.strip().split()[1:]) != 0]
        np.random.shuffle(annotations)
        
        for annotation in annotations:
            # fully parse annotations
            line = annotation.split()
            image_path, index = "", 1
            for i, one_line in enumerate(line):
                if not one_line.replace(",","").isnumeric():
                    if image_path != "": image_path += " "
                    image_path += one_line
                else:
                    index = i
                    break
            if not os.path.exists(image_path):
                raise KeyError("%s does not exist ... " %image_path)

            final_annotations.append([image_path, line[index:]])

        return final_annotations

    def __iter__(self): # iter, next
        return self

    def __next__(self):
        with tf.device('/cpu:0'):
            self.train_input_size = random.choice([self.train_input_sizes])
            self.train_output_sizes = self.train_input_size // self.strides

            batch_image = np.zeros((self.batch_size, self.train_input_size, self.train_input_size, 3), dtype=np.float32)
            # 빈 batch 이미지 정의해놓는다.
            batch_label_sbbox = np.zeros((self.batch_size, self.train_output_sizes[0], self.train_output_sizes[0],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_mbbox = np.zeros((self.batch_size, self.train_output_sizes[1], self.train_output_sizes[1],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            batch_label_lbbox = np.zeros((self.batch_size, self.train_output_sizes[2], self.train_output_sizes[2],
                                          self.anchor_per_scale, 5 + self.num_classes), dtype=np.float32)
            # feature map 3개의 사이즈를 만든다. 
            batch_sbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_mbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)
            batch_lbboxes = np.zeros((self.batch_size, self.max_bbox_per_scale, 4), dtype=np.float32)

            num = 0
            if self.batch_count < self.num_batchs:
                while num < self.batch_size:
                    index = self.batch_count * self.batch_size + num
                    if index >= self.num_samples: index -= self.num_samples
                    annotation = self.annotations[index]
                    image, bboxes = self.parse_annotation(annotation)
                    label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes = self.preprocess_true_boxes(bboxes)

                    batch_image[num, :, :, :] = image
                    batch_label_sbbox[num, :, :, :, :] = label_sbbox
                    batch_label_mbbox[num, :, :, :, :] = label_mbbox
                    batch_label_lbbox[num, :, :, :, :] = label_lbbox
                    batch_sbboxes[num, :, :] = sbboxes
                    batch_mbboxes[num, :, :] = mbboxes
                    batch_lbboxes[num, :, :] = lbboxes
                    num += 1
                self.batch_count += 1
                batch_smaller_target = batch_label_sbbox, batch_sbboxes
                batch_medium_target  = batch_label_mbbox, batch_mbboxes
                batch_larger_target  = batch_label_lbbox, batch_lbboxes

                return batch_image, (batch_smaller_target, batch_medium_target, batch_larger_target)
            else:
                self.batch_count = 0
                np.random.shuffle(self.annotations)
                raise StopIteration

    def random_horizontal_flip(self, image, bboxes):
        if random.random() < 0.5:
            _, w, _ = image.shape
            image = image[:, ::-1, :]
            bboxes[:, [0,2]] = w - bboxes[:, [2,0]]

        return image, bboxes

    def random_crop(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            crop_xmin = max(0, int(max_bbox[0] - random.uniform(0, max_l_trans)))
            crop_ymin = max(0, int(max_bbox[1] - random.uniform(0, max_u_trans)))
            crop_xmax = max(w, int(max_bbox[2] + random.uniform(0, max_r_trans)))
            crop_ymax = max(h, int(max_bbox[3] + random.uniform(0, max_d_trans)))

            image = image[crop_ymin : crop_ymax, crop_xmin : crop_xmax]

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] - crop_xmin
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] - crop_ymin

        return image, bboxes

    def random_translate(self, image, bboxes):
        if random.random() < 0.5:
            h, w, _ = image.shape
            max_bbox = np.concatenate([np.min(bboxes[:, 0:2], axis=0), np.max(bboxes[:, 2:4], axis=0)], axis=-1)

            max_l_trans = max_bbox[0]
            max_u_trans = max_bbox[1]
            max_r_trans = w - max_bbox[2]
            max_d_trans = h - max_bbox[3]

            tx = random.uniform(-(max_l_trans - 1), (max_r_trans - 1))
            ty = random.uniform(-(max_u_trans - 1), (max_d_trans - 1))

            M = np.array([[1, 0, tx], [0, 1, ty]])
            image = cv2.warpAffine(image, M, (w, h))

            bboxes[:, [0, 2]] = bboxes[:, [0, 2]] + tx
            bboxes[:, [1, 3]] = bboxes[:, [1, 3]] + ty

        return image, bboxes

    def parse_annotation(self, annotation):

        image_path = annotation[0]
        image = cv2.imread(image_path)
            
        bboxes = np.array([list(map(int, box.split(','))) for box in annotation[1]])

        if self.data_aug:
            image, bboxes = self.random_horizontal_flip(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_crop(np.copy(image), np.copy(bboxes))
            image, bboxes = self.random_translate(np.copy(image), np.copy(bboxes))

        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image, bboxes = image_preprocess(np.copy(image), [self.train_input_size, self.train_input_size], np.copy(bboxes))
        return image, bboxes

    def preprocess_true_boxes(self, bboxes):
        label = [np.zeros((self.train_output_sizes[i], self.train_output_sizes[i], self.anchor_per_scale,
                           5 + self.num_classes)) for i in range(3)]
        bboxes_xywh = [np.zeros((self.max_bbox_per_scale, 4)) for _ in range(3)]
        bbox_count = np.zeros((3,))

        for bbox in bboxes:
            bbox_coor = bbox[:4]
            bbox_class_ind = bbox[4]

            onehot = np.zeros(self.num_classes, dtype=np.float)
            onehot[bbox_class_ind] = 1.0
            uniform_distribution = np.full(self.num_classes, 1.0 / self.num_classes)
            deta = 0.01
            smooth_onehot = onehot * (1 - deta) + deta * uniform_distribution

            bbox_xywh = np.concatenate([(bbox_coor[2:] + bbox_coor[:2]) * 0.5, bbox_coor[2:] - bbox_coor[:2]], axis=-1)
            bbox_xywh_scaled = 1.0 * bbox_xywh[np.newaxis, :] / self.strides[:, np.newaxis]

            iou = []
            exist_positive = False
            for i in range(3):
                anchors_xywh = np.zeros((self.anchor_per_scale, 4))
                anchors_xywh[:, 0:2] = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32) + 0.5
                anchors_xywh[:, 2:4] = self.anchors[i]

                iou_scale = bbox_iou(bbox_xywh_scaled[i][np.newaxis, :], anchors_xywh)
                iou.append(iou_scale)
                iou_mask = iou_scale > 0.3

                if np.any(iou_mask):
                    xind, yind = np.floor(bbox_xywh_scaled[i, 0:2]).astype(np.int32)

                    label[i][yind, xind, iou_mask, :] = 0
                    label[i][yind, xind, iou_mask, 0:4] = bbox_xywh
                    label[i][yind, xind, iou_mask, 4:5] = 1.0
                    label[i][yind, xind, iou_mask, 5:] = smooth_onehot

                    bbox_ind = int(bbox_count[i] % self.max_bbox_per_scale)
                    bboxes_xywh[i][bbox_ind, :4] = bbox_xywh
                    bbox_count[i] += 1

                    exist_positive = True

            if not exist_positive:
                best_anchor_ind = np.argmax(np.array(iou).reshape(-1), axis=-1)
                best_detect = int(best_anchor_ind / self.anchor_per_scale)
                best_anchor = int(best_anchor_ind % self.anchor_per_scale)
                xind, yind = np.floor(bbox_xywh_scaled[best_detect, 0:2]).astype(np.int32)

                label[best_detect][yind, xind, best_anchor, :] = 0
                label[best_detect][yind, xind, best_anchor, 0:4] = bbox_xywh
                label[best_detect][yind, xind, best_anchor, 4:5] = 1.0
                label[best_detect][yind, xind, best_anchor, 5:] = smooth_onehot
                
                bbox_ind = int(bbox_count[best_detect] % self.max_bbox_per_scale)
                bboxes_xywh[best_detect][bbox_ind, :4] = bbox_xywh
                bbox_count[best_detect] += 1

        label_sbbox, label_mbbox, label_lbbox = label
        sbboxes, mbboxes, lbboxes = bboxes_xywh
        return label_sbbox, label_mbbox, label_lbbox, sbboxes, mbboxes, lbboxes

    def __len__(self):
        return self.num_batchs

# %% [markdown]
# https://www.tensorflow.org/guide/autodiff

# %% [markdown]
# **trainingblock**

# %%
global TRAIN_FROM_CHECKPOINT

# %%
trainset = Dataset('train')
testset = Dataset('test')

# %%
import shutil
import numpy as np
import tensorflow as tf

input_size = YOLO_INPUT_SIZE
Darknet_weights = YOLO_DARKNET_WEIGHTS


save_best_only = True # saves only best model according validation loss
save_checkpoints = False # saves all best validated checkpoints in training process (may require a lot disk space)

steps_per_epoch = len(trainset)
global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = TRAIN_WARMUP_EPOCHS * steps_per_epoch
total_steps = TRAIN_EPOCHS * steps_per_epoch

if TRAIN_TRANSFER:
    Darknet = Create_Yolov3(input_size=input_size)
    load_yolo_weights(Darknet, Darknet_weights) # use darknet weights

yolo = Create_Yolov3(input_size=input_size, training=True, CLASSES=TRAIN_CLASSES)


if TRAIN_FROM_CHECKPOINT:
    yolo.load_weights(TRAIN_FROM_CHECKPOINT)


optimizer = tf.keras.optimizers.Adam()

def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0
        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]
        total_loss = giou_loss + conf_loss + prob_loss
        gradients = tape.gradient(total_loss, yolo.trainable_variables)
        optimizer.apply_gradients(zip(gradients, yolo.trainable_variables))


        # update learning rate
        global_steps.assign_add(1)
        if global_steps < warmup_steps:# and not TRAIN_TRANSFER:
            lr = global_steps / warmup_steps * TRAIN_LR_INIT
        else:
            lr = TRAIN_LR_END + 0.5 * (TRAIN_LR_INIT - TRAIN_LR_END)*(
                (1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * np.pi)))
        optimizer.lr.assign(lr.numpy())

    return global_steps.numpy(), optimizer.lr.numpy(), giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()



def validate_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=False)
        giou_loss=conf_loss=prob_loss=0

        # optimizing process
        for i in range(3):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]

        total_loss = giou_loss + conf_loss + prob_loss
        
    return giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()


best_val_loss = 1000 # should be large at start


for epoch in range(TRAIN_EPOCHS):
    for image_data, target in trainset:
        results = train_step(image_data, target)
        cur_step = results[0]%steps_per_epoch
        print("epoch:{:2.0f} step:{:5.0f}/{}, lr:{:.6f}, giou_loss:{:7.2f}, conf_loss:{:7.2f}, prob_loss:{:7.2f}, total_loss:{:7.2f}"
                  .format(epoch, cur_step, steps_per_epoch, results[1], results[2], results[3], results[4], results[5]))
        
    count, giou_val, conf_val, prob_val, total_val = 0., 0, 0, 0, 0
    for image_data, target in testset:
        results = validate_step(image_data, target)
        count += 1
        giou_val += results[0]
        conf_val += results[1]
        prob_val += results[2]
        total_val += results[3]

        
    print("\n\ngiou_val_loss:{:7.2f}, conf_val_loss:{:7.2f}, prob_val_loss:{:7.2f}, total_val_loss:{:7.2f}\n\n".
          format(giou_val/count, conf_val/count, prob_val/count, total_val/count))

    if save_best_only and best_val_loss > total_val/count: 
        yolo.save_weights("./checkpoints/yolov3_custom")
        best_val_loss = total_val/count
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:183: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# epoch: 0 step:    2/60, lr:0.000002, giou_loss:   1.70, conf_loss:1880.26, prob_loss:   4.36, total_loss:1886.33
# epoch: 0 step:    3/60, lr:0.000002, giou_loss:   1.60, conf_loss:1829.28, prob_loss:   4.05, total_loss:1834.93
# epoch: 0 step:    4/60, lr:0.000003, giou_loss:   2.10, conf_loss:1874.58, prob_loss:   4.55, total_loss:1881.23
# epoch: 0 step:    5/60, lr:0.000004, giou_loss:   1.17, conf_loss:1872.24, prob_loss:   3.05, total_loss:1876.46
# epoch: 0 step:    6/60, lr:0.000005, giou_loss:   2.28, conf_loss:1831.63, prob_loss:   3.87, total_loss:1837.78
# epoch: 0 step:    7/60, lr:0.000006, giou_loss:   2.17, conf_loss:1822.82, prob_loss:   4.65, total_loss:1829.64
# epoch: 0 step:    8/60, lr:0.000007, giou_loss:   1.61, conf_loss:1813.63, prob_loss:   3.92, total_loss:1819.15
# epoch: 0 step:    9/60, lr:0.000007, giou_loss:   1.31, conf_loss:1812.99, prob_loss:   3.66, total_loss:1817.96
# epoch: 0 step:   10/60, lr:0.000008, giou_loss:   1.78, conf_loss:1720.36, prob_loss:   4.11, total_loss:1726.25
# epoch: 0 step:   11/60, lr:0.000009, giou_loss:   2.62, conf_loss:1727.68, prob_loss:   3.89, total_loss:1734.18
# epoch: 0 step:   12/60, lr:0.000010, giou_loss:   1.56, conf_loss:1682.35, prob_loss:   4.00, total_loss:1687.92
# epoch: 0 step:   13/60, lr:0.000011, giou_loss:   1.90, conf_loss:1674.02, prob_loss:   4.47, total_loss:1680.39
# epoch: 0 step:   14/60, lr:0.000012, giou_loss:   2.39, conf_loss:1672.04, prob_loss:   3.40, total_loss:1677.83
# epoch: 0 step:   15/60, lr:0.000012, giou_loss:   1.67, conf_loss:1645.27, prob_loss:   3.64, total_loss:1650.58
# epoch: 0 step:   16/60, lr:0.000013, giou_loss:   1.73, conf_loss:1589.75, prob_loss:   4.09, total_loss:1595.57
# epoch: 0 step:   17/60, lr:0.000014, giou_loss:   2.10, conf_loss:1588.07, prob_loss:   4.62, total_loss:1594.79
# epoch: 0 step:   18/60, lr:0.000015, giou_loss:   2.55, conf_loss:1570.84, prob_loss:   5.17, total_loss:1578.56
# epoch: 0 step:   19/60, lr:0.000016, giou_loss:   1.89, conf_loss:1551.37, prob_loss:   4.92, total_loss:1558.18
# epoch: 0 step:   20/60, lr:0.000017, giou_loss:   1.50, conf_loss:1533.80, prob_loss:   3.71, total_loss:1539.01
# epoch: 0 step:   21/60, lr:0.000018, giou_loss:   2.32, conf_loss:1511.21, prob_loss:   4.51, total_loss:1518.03
# epoch: 0 step:   22/60, lr:0.000018, giou_loss:   1.70, conf_loss:1497.07, prob_loss:   4.28, total_loss:1503.05
# epoch: 0 step:   23/60, lr:0.000019, giou_loss:   2.04, conf_loss:1477.72, prob_loss:   4.19, total_loss:1483.95
# epoch: 0 step:   24/60, lr:0.000020, giou_loss:   2.58, conf_loss:1465.89, prob_loss:   5.82, total_loss:1474.29
# epoch: 0 step:   25/60, lr:0.000021, giou_loss:   2.30, conf_loss:1446.01, prob_loss:   5.21, total_loss:1453.53
# epoch: 0 step:   26/60, lr:0.000022, giou_loss:   1.56, conf_loss:1421.28, prob_loss:   4.03, total_loss:1426.87
# epoch: 0 step:   27/60, lr:0.000023, giou_loss:   0.87, conf_loss:1425.23, prob_loss:   3.12, total_loss:1429.23
# epoch: 0 step:   28/60, lr:0.000023, giou_loss:   2.21, conf_loss:1398.10, prob_loss:   4.07, total_loss:1404.38
# epoch: 0 step:   29/60, lr:0.000024, giou_loss:   2.11, conf_loss:1396.04, prob_loss:   3.62, total_loss:1401.77
# epoch: 0 step:   30/60, lr:0.000025, giou_loss:   2.58, conf_loss:1371.52, prob_loss:   4.26, total_loss:1378.35
# epoch: 0 step:   31/60, lr:0.000026, giou_loss:   2.81, conf_loss:1359.43, prob_loss:   5.57, total_loss:1367.81
# epoch: 0 step:   32/60, lr:0.000027, giou_loss:   1.03, conf_loss:1326.60, prob_loss:   3.07, total_loss:1330.70
# epoch: 0 step:   33/60, lr:0.000028, giou_loss:   2.14, conf_loss:1337.99, prob_loss:   4.65, total_loss:1344.78
# epoch: 0 step:   34/60, lr:0.000028, giou_loss:   1.11, conf_loss:1319.43, prob_loss:   4.04, total_loss:1324.58
# epoch: 0 step:   35/60, lr:0.000029, giou_loss:   1.72, conf_loss:1303.90, prob_loss:   4.08, total_loss:1309.69
# epoch: 0 step:   36/60, lr:0.000030, giou_loss:   1.64, conf_loss:1287.42, prob_loss:   4.04, total_loss:1293.10
# epoch: 0 step:   37/60, lr:0.000031, giou_loss:   1.55, conf_loss:1278.12, prob_loss:   3.97, total_loss:1283.64
# epoch: 0 step:   38/60, lr:0.000032, giou_loss:   1.51, conf_loss:1263.08, prob_loss:   3.89, total_loss:1268.48
# epoch: 0 step:   39/60, lr:0.000033, giou_loss:   1.97, conf_loss:1225.55, prob_loss:   4.92, total_loss:1232.44
# epoch: 0 step:   40/60, lr:0.000033, giou_loss:   1.53, conf_loss:1219.88, prob_loss:   4.35, total_loss:1225.75
# epoch: 0 step:   41/60, lr:0.000034, giou_loss:   1.29, conf_loss:1211.92, prob_loss:   4.13, total_loss:1217.34
# epoch: 0 step:   42/60, lr:0.000035, giou_loss:   1.35, conf_loss:1194.53, prob_loss:   4.07, total_loss:1199.95
# epoch: 0 step:   43/60, lr:0.000036, giou_loss:   1.69, conf_loss:1187.55, prob_loss:   4.39, total_loss:1193.63
# epoch: 0 step:   44/60, lr:0.000037, giou_loss:   1.24, conf_loss:1172.83, prob_loss:   3.91, total_loss:1177.97
# epoch: 0 step:   45/60, lr:0.000038, giou_loss:   1.61, conf_loss:1141.55, prob_loss:   3.77, total_loss:1146.94
# epoch: 0 step:   46/60, lr:0.000038, giou_loss:   1.36, conf_loss:1141.94, prob_loss:   3.24, total_loss:1146.54
# epoch: 0 step:   47/60, lr:0.000039, giou_loss:   1.26, conf_loss:1107.61, prob_loss:   3.59, total_loss:1112.46
# epoch: 0 step:   48/60, lr:0.000040, giou_loss:   0.82, conf_loss:1100.41, prob_loss:   2.95, total_loss:1104.19
# epoch: 0 step:   49/60, lr:0.000041, giou_loss:   1.40, conf_loss:1068.08, prob_loss:   4.55, total_loss:1074.03
# epoch: 0 step:   50/60, lr:0.000042, giou_loss:   1.57, conf_loss:1046.36, prob_loss:   4.10, total_loss:1052.03
# epoch: 0 step:   51/60, lr:0.000042, giou_loss:   1.51, conf_loss:1052.63, prob_loss:   3.78, total_loss:1057.92
# epoch: 0 step:   52/60, lr:0.000043, giou_loss:   1.90, conf_loss:1043.43, prob_loss:   4.37, total_loss:1049.70
# epoch: 0 step:   53/60, lr:0.000044, giou_loss:   0.95, conf_loss:1032.43, prob_loss:   2.93, total_loss:1036.30
# epoch: 0 step:   54/60, lr:0.000045, giou_loss:   1.50, conf_loss: 997.21, prob_loss:   3.17, total_loss:1001.87
# epoch: 0 step:   55/60, lr:0.000046, giou_loss:   1.87, conf_loss: 961.95, prob_loss:   4.07, total_loss: 967.89
# epoch: 0 step:   56/60, lr:0.000047, giou_loss:   1.98, conf_loss: 960.52, prob_loss:   5.09, total_loss: 967.59
# epoch: 0 step:   57/60, lr:0.000048, giou_loss:   1.07, conf_loss: 947.73, prob_loss:   2.55, total_loss: 951.36
# epoch: 0 step:   58/60, lr:0.000048, giou_loss:   1.24, conf_loss: 936.01, prob_loss:   3.15, total_loss: 940.40
# epoch: 0 step:   59/60, lr:0.000049, giou_loss:   1.13, conf_loss: 921.89, prob_loss:   3.53, total_loss: 926.55
# epoch: 0 step:    0/60, lr:0.000050, giou_loss:   1.92, conf_loss: 935.76, prob_loss:   4.54, total_loss: 942.22
# epoch: 0 step:    1/60, lr:0.000051, giou_loss:   1.28, conf_loss: 907.86, prob_loss:   3.86, total_loss: 913.00
#
#
# giou_val_loss:   1.80, conf_val_loss:1801.51, prob_val_loss:   4.33, total_val_loss:1807.63
#
#
# epoch: 1 step:    2/60, lr:0.000052, giou_loss:   2.20, conf_loss: 900.67, prob_loss:   4.66, total_loss: 907.53
# epoch: 1 step:    3/60, lr:0.000052, giou_loss:   1.05, conf_loss: 880.11, prob_loss:   3.01, total_loss: 884.17
# epoch: 1 step:    4/60, lr:0.000053, giou_loss:   1.51, conf_loss: 874.57, prob_loss:   4.16, total_loss: 880.25
# epoch: 1 step:    5/60, lr:0.000054, giou_loss:   1.01, conf_loss: 845.63, prob_loss:   3.70, total_loss: 850.34
# epoch: 1 step:    6/60, lr:0.000055, giou_loss:   1.26, conf_loss: 834.14, prob_loss:   4.21, total_loss: 839.61
# epoch: 1 step:    7/60, lr:0.000056, giou_loss:   1.47, conf_loss: 823.93, prob_loss:   3.91, total_loss: 829.31
# epoch: 1 step:    8/60, lr:0.000057, giou_loss:   1.66, conf_loss: 807.78, prob_loss:   3.88, total_loss: 813.33
# epoch: 1 step:    9/60, lr:0.000058, giou_loss:   1.89, conf_loss: 820.75, prob_loss:   4.14, total_loss: 826.77
# epoch: 1 step:   10/60, lr:0.000058, giou_loss:   1.23, conf_loss: 792.03, prob_loss:   3.21, total_loss: 796.47
# epoch: 1 step:   11/60, lr:0.000059, giou_loss:   0.82, conf_loss: 801.36, prob_loss:   2.73, total_loss: 804.91
# epoch: 1 step:   12/60, lr:0.000060, giou_loss:   1.87, conf_loss: 784.62, prob_loss:   4.30, total_loss: 790.79
# epoch: 1 step:   13/60, lr:0.000061, giou_loss:   1.04, conf_loss: 764.49, prob_loss:   3.28, total_loss: 768.81
# epoch: 1 step:   14/60, lr:0.000062, giou_loss:   1.35, conf_loss: 762.63, prob_loss:   3.13, total_loss: 767.10
# epoch: 1 step:   15/60, lr:0.000063, giou_loss:   1.24, conf_loss: 754.53, prob_loss:   2.81, total_loss: 758.58
# epoch: 1 step:   16/60, lr:0.000063, giou_loss:   1.60, conf_loss: 755.61, prob_loss:   3.49, total_loss: 760.69
# epoch: 1 step:   17/60, lr:0.000064, giou_loss:   1.88, conf_loss: 734.75, prob_loss:   3.38, total_loss: 740.01
# epoch: 1 step:   18/60, lr:0.000065, giou_loss:   2.20, conf_loss: 725.58, prob_loss:   3.82, total_loss: 731.60
# epoch: 1 step:   19/60, lr:0.000066, giou_loss:   1.65, conf_loss: 715.53, prob_loss:   4.30, total_loss: 721.48
# epoch: 1 step:   20/60, lr:0.000067, giou_loss:   1.08, conf_loss: 707.12, prob_loss:   3.96, total_loss: 712.16
# epoch: 1 step:   21/60, lr:0.000067, giou_loss:   1.04, conf_loss: 694.11, prob_loss:   2.78, total_loss: 697.93
# epoch: 1 step:   22/60, lr:0.000068, giou_loss:   1.89, conf_loss: 688.57, prob_loss:   4.30, total_loss: 694.76
# epoch: 1 step:   23/60, lr:0.000069, giou_loss:   1.01, conf_loss: 678.02, prob_loss:   2.71, total_loss: 681.74
# epoch: 1 step:   24/60, lr:0.000070, giou_loss:   0.89, conf_loss: 672.25, prob_loss:   3.06, total_loss: 676.20
# epoch: 1 step:   25/60, lr:0.000071, giou_loss:   1.26, conf_loss: 667.97, prob_loss:   3.75, total_loss: 672.98
# epoch: 1 step:   26/60, lr:0.000072, giou_loss:   1.11, conf_loss: 651.22, prob_loss:   2.41, total_loss: 654.74
# epoch: 1 step:   27/60, lr:0.000072, giou_loss:   1.82, conf_loss: 660.32, prob_loss:   3.53, total_loss: 665.67
# epoch: 1 step:   28/60, lr:0.000073, giou_loss:   1.45, conf_loss: 639.23, prob_loss:   3.88, total_loss: 644.56
# epoch: 1 step:   29/60, lr:0.000074, giou_loss:   1.33, conf_loss: 637.78, prob_loss:   3.32, total_loss: 642.43
# epoch: 1 step:   30/60, lr:0.000075, giou_loss:   1.34, conf_loss: 618.27, prob_loss:   3.51, total_loss: 623.12
# epoch: 1 step:   31/60, lr:0.000076, giou_loss:   1.07, conf_loss: 617.36, prob_loss:   3.66, total_loss: 622.09
# epoch: 1 step:   32/60, lr:0.000077, giou_loss:   1.04, conf_loss: 612.76, prob_loss:   3.72, total_loss: 617.52
# epoch: 1 step:   33/60, lr:0.000078, giou_loss:   1.04, conf_loss: 602.43, prob_loss:   3.18, total_loss: 606.65
# epoch: 1 step:   34/60, lr:0.000078, giou_loss:   1.64, conf_loss: 594.40, prob_loss:   3.82, total_loss: 599.86
# epoch: 1 step:   35/60, lr:0.000079, giou_loss:   0.86, conf_loss: 583.34, prob_loss:   3.07, total_loss: 587.26
# epoch: 1 step:   36/60, lr:0.000080, giou_loss:   0.84, conf_loss: 579.05, prob_loss:   2.74, total_loss: 582.63
# epoch: 1 step:   37/60, lr:0.000081, giou_loss:   2.21, conf_loss: 570.14, prob_loss:   3.70, total_loss: 576.05
# epoch: 1 step:   38/60, lr:0.000082, giou_loss:   0.75, conf_loss: 565.23, prob_loss:   3.56, total_loss: 569.54
# epoch: 1 step:   39/60, lr:0.000083, giou_loss:   0.86, conf_loss: 555.54, prob_loss:   3.34, total_loss: 559.74
# epoch: 1 step:   40/60, lr:0.000083, giou_loss:   1.17, conf_loss: 550.83, prob_loss:   3.98, total_loss: 555.97
# epoch: 1 step:   41/60, lr:0.000084, giou_loss:   1.33, conf_loss: 542.94, prob_loss:   3.09, total_loss: 547.36
# epoch: 1 step:   42/60, lr:0.000085, giou_loss:   1.07, conf_loss: 538.79, prob_loss:   4.09, total_loss: 543.96
# epoch: 1 step:   43/60, lr:0.000086, giou_loss:   0.99, conf_loss: 530.17, prob_loss:   2.88, total_loss: 534.05
# epoch: 1 step:   44/60, lr:0.000087, giou_loss:   0.93, conf_loss: 528.72, prob_loss:   3.62, total_loss: 533.26
# epoch: 1 step:   45/60, lr:0.000087, giou_loss:   1.39, conf_loss: 526.67, prob_loss:   3.69, total_loss: 531.75
# epoch: 1 step:   46/60, lr:0.000088, giou_loss:   1.41, conf_loss: 514.38, prob_loss:   3.00, total_loss: 518.79
# epoch: 1 step:   47/60, lr:0.000089, giou_loss:   1.20, conf_loss: 520.72, prob_loss:   2.82, total_loss: 524.73
# epoch: 1 step:   48/60, lr:0.000090, giou_loss:   1.29, conf_loss: 504.84, prob_loss:   4.55, total_loss: 510.68
# epoch: 1 step:   49/60, lr:0.000091, giou_loss:   1.43, conf_loss: 498.50, prob_loss:   3.36, total_loss: 503.30
# epoch: 1 step:   50/60, lr:0.000092, giou_loss:   1.24, conf_loss: 490.00, prob_loss:   4.17, total_loss: 495.41
# epoch: 1 step:   51/60, lr:0.000092, giou_loss:   1.70, conf_loss: 480.47, prob_loss:   2.74, total_loss: 484.91
# epoch: 1 step:   52/60, lr:0.000093, giou_loss:   1.23, conf_loss: 476.00, prob_loss:   2.26, total_loss: 479.50
# epoch: 1 step:   53/60, lr:0.000094, giou_loss:   1.50, conf_loss: 474.63, prob_loss:   3.74, total_loss: 479.86
# epoch: 1 step:   54/60, lr:0.000095, giou_loss:   1.55, conf_loss: 465.30, prob_loss:   3.65, total_loss: 470.51
# epoch: 1 step:   55/60, lr:0.000096, giou_loss:   2.80, conf_loss: 460.58, prob_loss:   4.96, total_loss: 468.34
# epoch: 1 step:   56/60, lr:0.000097, giou_loss:   1.26, conf_loss: 456.82, prob_loss:   3.66, total_loss: 461.74
# epoch: 1 step:   57/60, lr:0.000098, giou_loss:   1.12, conf_loss: 446.31, prob_loss:   3.46, total_loss: 450.89
# epoch: 1 step:   58/60, lr:0.000098, giou_loss:   0.75, conf_loss: 444.44, prob_loss:   2.67, total_loss: 447.87
# epoch: 1 step:   59/60, lr:0.000099, giou_loss:   1.08, conf_loss: 434.55, prob_loss:   1.83, total_loss: 437.47
# epoch: 1 step:    0/60, lr:0.000100, giou_loss:   1.04, conf_loss: 434.88, prob_loss:   3.21, total_loss: 439.13
# epoch: 1 step:    1/60, lr:0.000100, giou_loss:   1.56, conf_loss: 424.00, prob_loss:   2.71, total_loss: 428.28
#
#
# giou_val_loss:   1.74, conf_val_loss:1435.05, prob_val_loss:   4.27, total_val_loss:1441.06
#
#
# epoch: 2 step:    2/60, lr:0.000100, giou_loss:   0.85, conf_loss: 418.07, prob_loss:   2.89, total_loss: 421.81
# epoch: 2 step:    3/60, lr:0.000100, giou_loss:   0.97, conf_loss: 412.49, prob_loss:   3.68, total_loss: 417.14
# epoch: 2 step:    4/60, lr:0.000100, giou_loss:   1.55, conf_loss: 408.06, prob_loss:   3.43, total_loss: 413.04
# epoch: 2 step:    5/60, lr:0.000100, giou_loss:   1.28, conf_loss: 402.90, prob_loss:   3.36, total_loss: 407.55
# epoch: 2 step:    6/60, lr:0.000100, giou_loss:   1.58, conf_loss: 399.91, prob_loss:   2.77, total_loss: 404.27
# epoch: 2 step:    7/60, lr:0.000100, giou_loss:   2.12, conf_loss: 389.83, prob_loss:   3.93, total_loss: 395.88
# epoch: 2 step:    8/60, lr:0.000100, giou_loss:   1.17, conf_loss: 386.77, prob_loss:   3.30, total_loss: 391.24
# epoch: 2 step:    9/60, lr:0.000100, giou_loss:   1.13, conf_loss: 383.80, prob_loss:   3.27, total_loss: 388.20
# epoch: 2 step:   10/60, lr:0.000100, giou_loss:   1.12, conf_loss: 378.54, prob_loss:   3.18, total_loss: 382.84
# epoch: 2 step:   11/60, lr:0.000100, giou_loss:   1.30, conf_loss: 374.72, prob_loss:   3.86, total_loss: 379.89
# epoch: 2 step:   12/60, lr:0.000100, giou_loss:   1.67, conf_loss: 369.77, prob_loss:   2.46, total_loss: 373.90
# epoch: 2 step:   13/60, lr:0.000100, giou_loss:   1.12, conf_loss: 366.66, prob_loss:   2.85, total_loss: 370.64
# epoch: 2 step:   14/60, lr:0.000100, giou_loss:   1.62, conf_loss: 359.24, prob_loss:   3.51, total_loss: 364.38
# epoch: 2 step:   15/60, lr:0.000100, giou_loss:   1.32, conf_loss: 354.13, prob_loss:   3.29, total_loss: 358.74
# epoch: 2 step:   16/60, lr:0.000100, giou_loss:   1.24, conf_loss: 349.74, prob_loss:   2.32, total_loss: 353.30
# epoch: 2 step:   17/60, lr:0.000100, giou_loss:   0.88, conf_loss: 347.96, prob_loss:   2.68, total_loss: 351.52
# epoch: 2 step:   18/60, lr:0.000100, giou_loss:   1.20, conf_loss: 343.91, prob_loss:   3.76, total_loss: 348.87
# epoch: 2 step:   19/60, lr:0.000100, giou_loss:   1.17, conf_loss: 337.46, prob_loss:   2.83, total_loss: 341.45
# epoch: 2 step:   20/60, lr:0.000100, giou_loss:   1.69, conf_loss: 335.24, prob_loss:   3.54, total_loss: 340.47
# epoch: 2 step:   21/60, lr:0.000100, giou_loss:   1.57, conf_loss: 331.34, prob_loss:   2.82, total_loss: 335.73
# epoch: 2 step:   22/60, lr:0.000100, giou_loss:   0.90, conf_loss: 325.57, prob_loss:   2.23, total_loss: 328.69
# epoch: 2 step:   23/60, lr:0.000100, giou_loss:   0.87, conf_loss: 322.10, prob_loss:   3.81, total_loss: 326.78
# epoch: 2 step:   24/60, lr:0.000100, giou_loss:   1.27, conf_loss: 321.67, prob_loss:   3.36, total_loss: 326.30
# epoch: 2 step:   25/60, lr:0.000099, giou_loss:   1.84, conf_loss: 319.06, prob_loss:   3.30, total_loss: 324.20
# epoch: 2 step:   26/60, lr:0.000099, giou_loss:   1.53, conf_loss: 311.96, prob_loss:   4.60, total_loss: 318.09
# epoch: 2 step:   27/60, lr:0.000099, giou_loss:   1.36, conf_loss: 307.17, prob_loss:   2.16, total_loss: 310.70
# epoch: 2 step:   28/60, lr:0.000099, giou_loss:   1.48, conf_loss: 303.65, prob_loss:   4.31, total_loss: 309.44
# epoch: 2 step:   29/60, lr:0.000099, giou_loss:   1.65, conf_loss: 298.94, prob_loss:   1.66, total_loss: 302.25
# epoch: 2 step:   30/60, lr:0.000099, giou_loss:   1.87, conf_loss: 300.27, prob_loss:   4.04, total_loss: 306.18
# epoch: 2 step:   31/60, lr:0.000099, giou_loss:   1.36, conf_loss: 295.77, prob_loss:   1.97, total_loss: 299.10
# epoch: 2 step:   32/60, lr:0.000099, giou_loss:   1.16, conf_loss: 289.81, prob_loss:   2.49, total_loss: 293.46
# epoch: 2 step:   33/60, lr:0.000099, giou_loss:   1.30, conf_loss: 293.09, prob_loss:   1.52, total_loss: 295.90
# epoch: 2 step:   34/60, lr:0.000099, giou_loss:   0.89, conf_loss: 285.52, prob_loss:   1.76, total_loss: 288.17
# epoch: 2 step:   35/60, lr:0.000099, giou_loss:   2.52, conf_loss: 282.77, prob_loss:   3.75, total_loss: 289.04
# epoch: 2 step:   36/60, lr:0.000099, giou_loss:   1.40, conf_loss: 278.39, prob_loss:   3.01, total_loss: 282.81
# epoch: 2 step:   37/60, lr:0.000099, giou_loss:   1.53, conf_loss: 278.87, prob_loss:   2.06, total_loss: 282.46
# epoch: 2 step:   38/60, lr:0.000099, giou_loss:   0.69, conf_loss: 272.95, prob_loss:   1.71, total_loss: 275.34
# epoch: 2 step:   39/60, lr:0.000099, giou_loss:   1.29, conf_loss: 269.75, prob_loss:   2.55, total_loss: 273.59
# epoch: 2 step:   40/60, lr:0.000099, giou_loss:   1.56, conf_loss: 266.71, prob_loss:   3.58, total_loss: 271.85
# epoch: 2 step:   41/60, lr:0.000099, giou_loss:   1.12, conf_loss: 267.54, prob_loss:   2.64, total_loss: 271.30
# epoch: 2 step:   42/60, lr:0.000099, giou_loss:   1.35, conf_loss: 260.41, prob_loss:   2.64, total_loss: 264.40
# epoch: 2 step:   43/60, lr:0.000098, giou_loss:   1.18, conf_loss: 259.93, prob_loss:   1.80, total_loss: 262.91
# epoch: 2 step:   44/60, lr:0.000098, giou_loss:   1.16, conf_loss: 259.48, prob_loss:   1.23, total_loss: 261.88
# epoch: 2 step:   45/60, lr:0.000098, giou_loss:   1.24, conf_loss: 253.93, prob_loss:   4.30, total_loss: 259.47
# epoch: 2 step:   46/60, lr:0.000098, giou_loss:   1.69, conf_loss: 250.37, prob_loss:   3.28, total_loss: 255.34
# epoch: 2 step:   47/60, lr:0.000098, giou_loss:   1.09, conf_loss: 254.27, prob_loss:   2.74, total_loss: 258.10
# epoch: 2 step:   48/60, lr:0.000098, giou_loss:   1.16, conf_loss: 248.45, prob_loss:   2.81, total_loss: 252.42
# epoch: 2 step:   49/60, lr:0.000098, giou_loss:   1.12, conf_loss: 242.75, prob_loss:   1.24, total_loss: 245.11
# epoch: 2 step:   50/60, lr:0.000098, giou_loss:   0.79, conf_loss: 243.62, prob_loss:   1.88, total_loss: 246.30
# epoch: 2 step:   51/60, lr:0.000098, giou_loss:   1.30, conf_loss: 238.50, prob_loss:   4.14, total_loss: 243.95
# epoch: 2 step:   52/60, lr:0.000098, giou_loss:   1.57, conf_loss: 239.00, prob_loss:   2.61, total_loss: 243.18
# epoch: 2 step:   53/60, lr:0.000098, giou_loss:   1.02, conf_loss: 238.82, prob_loss:   2.80, total_loss: 242.65
# epoch: 2 step:   54/60, lr:0.000098, giou_loss:   1.07, conf_loss: 230.62, prob_loss:   2.63, total_loss: 234.33
# epoch: 2 step:   55/60, lr:0.000097, giou_loss:   1.70, conf_loss: 231.42, prob_loss:   2.11, total_loss: 235.23
# epoch: 2 step:   56/60, lr:0.000097, giou_loss:   1.44, conf_loss: 228.10, prob_loss:   2.29, total_loss: 231.83
# epoch: 2 step:   57/60, lr:0.000097, giou_loss:   2.27, conf_loss: 228.04, prob_loss:   3.01, total_loss: 233.33
# epoch: 2 step:   58/60, lr:0.000097, giou_loss:   1.47, conf_loss: 224.00, prob_loss:   2.08, total_loss: 227.55
# epoch: 2 step:   59/60, lr:0.000097, giou_loss:   1.32, conf_loss: 223.21, prob_loss:   1.82, total_loss: 226.34
# epoch: 2 step:    0/60, lr:0.000097, giou_loss:   1.92, conf_loss: 221.77, prob_loss:   2.39, total_loss: 226.08
# epoch: 2 step:    1/60, lr:0.000097, giou_loss:   0.89, conf_loss: 217.87, prob_loss:   2.40, total_loss: 221.16
#
#
# giou_val_loss:   1.70, conf_val_loss: 885.84, prob_val_loss:   4.18, total_val_loss: 891.73
#
#
# epoch: 3 step:    2/60, lr:0.000097, giou_loss:   1.93, conf_loss: 216.14, prob_loss:   3.32, total_loss: 221.39
# epoch: 3 step:    3/60, lr:0.000097, giou_loss:   1.22, conf_loss: 213.19, prob_loss:   2.36, total_loss: 216.78
# epoch: 3 step:    4/60, lr:0.000097, giou_loss:   0.85, conf_loss: 212.76, prob_loss:   1.92, total_loss: 215.52
# epoch: 3 step:    5/60, lr:0.000096, giou_loss:   1.38, conf_loss: 211.60, prob_loss:   1.80, total_loss: 214.78
# epoch: 3 step:    6/60, lr:0.000096, giou_loss:   1.98, conf_loss: 208.32, prob_loss:   4.75, total_loss: 215.05
# epoch: 3 step:    7/60, lr:0.000096, giou_loss:   2.11, conf_loss: 206.22, prob_loss:   4.72, total_loss: 213.05
# epoch: 3 step:    8/60, lr:0.000096, giou_loss:   1.68, conf_loss: 205.45, prob_loss:   3.78, total_loss: 210.91
# epoch: 3 step:    9/60, lr:0.000096, giou_loss:   1.15, conf_loss: 201.28, prob_loss:   1.52, total_loss: 203.94
# epoch: 3 step:   10/60, lr:0.000096, giou_loss:   0.97, conf_loss: 200.78, prob_loss:   3.28, total_loss: 205.04
# epoch: 3 step:   11/60, lr:0.000096, giou_loss:   1.22, conf_loss: 197.80, prob_loss:   2.49, total_loss: 201.50
# epoch: 3 step:   12/60, lr:0.000096, giou_loss:   1.37, conf_loss: 196.02, prob_loss:   1.98, total_loss: 199.37
# epoch: 3 step:   13/60, lr:0.000096, giou_loss:   1.08, conf_loss: 195.03, prob_loss:   4.00, total_loss: 200.11
# epoch: 3 step:   14/60, lr:0.000095, giou_loss:   1.74, conf_loss: 192.89, prob_loss:   4.24, total_loss: 198.87
# epoch: 3 step:   15/60, lr:0.000095, giou_loss:   1.14, conf_loss: 190.08, prob_loss:   2.09, total_loss: 193.30
# epoch: 3 step:   16/60, lr:0.000095, giou_loss:   1.22, conf_loss: 189.39, prob_loss:   2.48, total_loss: 193.09
# epoch: 3 step:   17/60, lr:0.000095, giou_loss:   1.31, conf_loss: 188.59, prob_loss:   1.98, total_loss: 191.88
# epoch: 3 step:   18/60, lr:0.000095, giou_loss:   0.92, conf_loss: 185.05, prob_loss:   2.88, total_loss: 188.84
# epoch: 3 step:   19/60, lr:0.000095, giou_loss:   1.14, conf_loss: 185.55, prob_loss:   2.40, total_loss: 189.10
# epoch: 3 step:   20/60, lr:0.000095, giou_loss:   1.79, conf_loss: 182.29, prob_loss:   3.45, total_loss: 187.53
# epoch: 3 step:   21/60, lr:0.000095, giou_loss:   1.42, conf_loss: 183.04, prob_loss:   2.74, total_loss: 187.20
# epoch: 3 step:   22/60, lr:0.000094, giou_loss:   1.09, conf_loss: 178.69, prob_loss:   3.76, total_loss: 183.54
# epoch: 3 step:   23/60, lr:0.000094, giou_loss:   1.11, conf_loss: 180.21, prob_loss:   2.00, total_loss: 183.32
# epoch: 3 step:   24/60, lr:0.000094, giou_loss:   1.17, conf_loss: 176.17, prob_loss:   2.20, total_loss: 179.54
# epoch: 3 step:   25/60, lr:0.000094, giou_loss:   1.20, conf_loss: 176.00, prob_loss:   2.10, total_loss: 179.30
# epoch: 3 step:   26/60, lr:0.000094, giou_loss:   0.95, conf_loss: 172.93, prob_loss:   1.14, total_loss: 175.02
# epoch: 3 step:   27/60, lr:0.000094, giou_loss:   1.36, conf_loss: 173.52, prob_loss:   2.24, total_loss: 177.12
# epoch: 3 step:   28/60, lr:0.000094, giou_loss:   1.46, conf_loss: 171.61, prob_loss:   2.08, total_loss: 175.15
# epoch: 3 step:   29/60, lr:0.000093, giou_loss:   1.69, conf_loss: 168.89, prob_loss:   0.98, total_loss: 171.55
# epoch: 3 step:   30/60, lr:0.000093, giou_loss:   1.71, conf_loss: 169.64, prob_loss:   2.22, total_loss: 173.58
# epoch: 3 step:   31/60, lr:0.000093, giou_loss:   1.46, conf_loss: 166.81, prob_loss:   2.40, total_loss: 170.67
# epoch: 3 step:   32/60, lr:0.000093, giou_loss:   1.27, conf_loss: 165.82, prob_loss:   3.19, total_loss: 170.28
# epoch: 3 step:   33/60, lr:0.000093, giou_loss:   1.18, conf_loss: 164.72, prob_loss:   1.96, total_loss: 167.86
# epoch: 3 step:   34/60, lr:0.000093, giou_loss:   1.40, conf_loss: 162.70, prob_loss:   1.32, total_loss: 165.42
# epoch: 3 step:   35/60, lr:0.000093, giou_loss:   1.31, conf_loss: 162.70, prob_loss:   3.25, total_loss: 167.26
# epoch: 3 step:   36/60, lr:0.000092, giou_loss:   1.67, conf_loss: 159.54, prob_loss:   3.80, total_loss: 165.02
# epoch: 3 step:   37/60, lr:0.000092, giou_loss:   1.61, conf_loss: 159.07, prob_loss:   1.84, total_loss: 162.53
# epoch: 3 step:   38/60, lr:0.000092, giou_loss:   1.18, conf_loss: 159.09, prob_loss:   5.40, total_loss: 165.67
# epoch: 3 step:   39/60, lr:0.000092, giou_loss:   1.41, conf_loss: 158.36, prob_loss:   4.34, total_loss: 164.11
# epoch: 3 step:   40/60, lr:0.000092, giou_loss:   1.24, conf_loss: 155.57, prob_loss:   2.91, total_loss: 159.71
# epoch: 3 step:   41/60, lr:0.000092, giou_loss:   1.23, conf_loss: 154.09, prob_loss:   1.73, total_loss: 157.05
# epoch: 3 step:   42/60, lr:0.000091, giou_loss:   0.98, conf_loss: 151.98, prob_loss:   3.78, total_loss: 156.74
# epoch: 3 step:   43/60, lr:0.000091, giou_loss:   0.97, conf_loss: 153.02, prob_loss:   2.20, total_loss: 156.19
# epoch: 3 step:   44/60, lr:0.000091, giou_loss:   1.22, conf_loss: 150.85, prob_loss:   3.30, total_loss: 155.37
# epoch: 3 step:   45/60, lr:0.000091, giou_loss:   1.67, conf_loss: 149.55, prob_loss:   1.06, total_loss: 152.27
# epoch: 3 step:   46/60, lr:0.000091, giou_loss:   1.61, conf_loss: 149.21, prob_loss:   3.09, total_loss: 153.92
# epoch: 3 step:   47/60, lr:0.000091, giou_loss:   1.06, conf_loss: 147.85, prob_loss:   1.00, total_loss: 149.90
# epoch: 3 step:   48/60, lr:0.000090, giou_loss:   1.45, conf_loss: 147.00, prob_loss:   2.57, total_loss: 151.02
# epoch: 3 step:   49/60, lr:0.000090, giou_loss:   0.67, conf_loss: 144.57, prob_loss:   1.15, total_loss: 146.39
# epoch: 3 step:   50/60, lr:0.000090, giou_loss:   1.23, conf_loss: 142.88, prob_loss:   1.95, total_loss: 146.07
# epoch: 3 step:   51/60, lr:0.000090, giou_loss:   1.72, conf_loss: 145.42, prob_loss:   3.33, total_loss: 150.46
# epoch: 3 step:   52/60, lr:0.000090, giou_loss:   1.75, conf_loss: 142.54, prob_loss:   1.20, total_loss: 145.49
# epoch: 3 step:   53/60, lr:0.000090, giou_loss:   0.93, conf_loss: 140.15, prob_loss:   2.82, total_loss: 143.90
# epoch: 3 step:   54/60, lr:0.000089, giou_loss:   0.77, conf_loss: 140.92, prob_loss:   2.92, total_loss: 144.60
# epoch: 3 step:   55/60, lr:0.000089, giou_loss:   1.00, conf_loss: 139.01, prob_loss:   0.94, total_loss: 140.95
# epoch: 3 step:   56/60, lr:0.000089, giou_loss:   2.54, conf_loss: 137.79, prob_loss:   4.17, total_loss: 144.49
# epoch: 3 step:   57/60, lr:0.000089, giou_loss:   0.96, conf_loss: 136.15, prob_loss:   2.53, total_loss: 139.63
# epoch: 3 step:   58/60, lr:0.000089, giou_loss:   1.55, conf_loss: 136.99, prob_loss:   2.28, total_loss: 140.82
# epoch: 3 step:   59/60, lr:0.000089, giou_loss:   1.43, conf_loss: 135.96, prob_loss:   1.76, total_loss: 139.15
# epoch: 3 step:    0/60, lr:0.000088, giou_loss:   1.69, conf_loss: 135.38, prob_loss:   3.19, total_loss: 140.27
# epoch: 3 step:    1/60, lr:0.000088, giou_loss:   1.48, conf_loss: 132.58, prob_loss:   3.60, total_loss: 137.66
#
#
# giou_val_loss:   1.62, conf_val_loss: 479.22, prob_val_loss:   4.16, total_val_loss: 485.01
#
#
# epoch: 4 step:    2/60, lr:0.000088, giou_loss:   1.55, conf_loss: 132.11, prob_loss:   4.11, total_loss: 137.76
# epoch: 4 step:    3/60, lr:0.000088, giou_loss:   0.49, conf_loss: 132.43, prob_loss:   0.81, total_loss: 133.72
# epoch: 4 step:    4/60, lr:0.000088, giou_loss:   1.24, conf_loss: 131.90, prob_loss:   4.43, total_loss: 137.57
# epoch: 4 step:    5/60, lr:0.000087, giou_loss:   0.95, conf_loss: 129.15, prob_loss:   2.89, total_loss: 132.98
# epoch: 4 step:    6/60, lr:0.000087, giou_loss:   0.65, conf_loss: 128.34, prob_loss:   3.02, total_loss: 132.01
# epoch: 4 step:    7/60, lr:0.000087, giou_loss:   1.28, conf_loss: 127.86, prob_loss:   2.40, total_loss: 131.53
# epoch: 4 step:    8/60, lr:0.000087, giou_loss:   1.18, conf_loss: 126.59, prob_loss:   4.30, total_loss: 132.07
# epoch: 4 step:    9/60, lr:0.000087, giou_loss:   1.53, conf_loss: 126.89, prob_loss:   2.35, total_loss: 130.77
# epoch: 4 step:   10/60, lr:0.000086, giou_loss:   1.02, conf_loss: 124.76, prob_loss:   1.35, total_loss: 127.13
# epoch: 4 step:   11/60, lr:0.000086, giou_loss:   1.14, conf_loss: 125.34, prob_loss:   1.90, total_loss: 128.37
# epoch: 4 step:   12/60, lr:0.000086, giou_loss:   1.11, conf_loss: 122.88, prob_loss:   1.44, total_loss: 125.43
# epoch: 4 step:   13/60, lr:0.000086, giou_loss:   1.34, conf_loss: 122.39, prob_loss:   2.03, total_loss: 125.77
# epoch: 4 step:   14/60, lr:0.000086, giou_loss:   1.05, conf_loss: 122.85, prob_loss:   1.78, total_loss: 125.68
# epoch: 4 step:   15/60, lr:0.000085, giou_loss:   0.64, conf_loss: 120.33, prob_loss:   1.48, total_loss: 122.44
# epoch: 4 step:   16/60, lr:0.000085, giou_loss:   0.67, conf_loss: 119.64, prob_loss:   0.79, total_loss: 121.11
# epoch: 4 step:   17/60, lr:0.000085, giou_loss:   0.86, conf_loss: 118.77, prob_loss:   3.25, total_loss: 122.88
# epoch: 4 step:   18/60, lr:0.000085, giou_loss:   1.29, conf_loss: 121.33, prob_loss:   3.55, total_loss: 126.17
# epoch: 4 step:   19/60, lr:0.000085, giou_loss:   1.15, conf_loss: 118.68, prob_loss:   1.20, total_loss: 121.04
# epoch: 4 step:   20/60, lr:0.000084, giou_loss:   1.28, conf_loss: 119.13, prob_loss:   3.19, total_loss: 123.60
# epoch: 4 step:   21/60, lr:0.000084, giou_loss:   1.54, conf_loss: 116.72, prob_loss:   3.60, total_loss: 121.86
# epoch: 4 step:   22/60, lr:0.000084, giou_loss:   0.95, conf_loss: 116.29, prob_loss:   1.35, total_loss: 118.58
# epoch: 4 step:   23/60, lr:0.000084, giou_loss:   1.50, conf_loss: 117.31, prob_loss:   1.87, total_loss: 120.68
# epoch: 4 step:   24/60, lr:0.000083, giou_loss:   0.83, conf_loss: 115.41, prob_loss:   0.93, total_loss: 117.17
# epoch: 4 step:   25/60, lr:0.000083, giou_loss:   1.19, conf_loss: 114.81, prob_loss:   1.85, total_loss: 117.85
# epoch: 4 step:   26/60, lr:0.000083, giou_loss:   1.11, conf_loss: 113.45, prob_loss:   1.33, total_loss: 115.90
# epoch: 4 step:   27/60, lr:0.000083, giou_loss:   1.49, conf_loss: 114.24, prob_loss:   3.51, total_loss: 119.24
# epoch: 4 step:   28/60, lr:0.000083, giou_loss:   1.16, conf_loss: 113.05, prob_loss:   2.28, total_loss: 116.49
# epoch: 4 step:   29/60, lr:0.000082, giou_loss:   1.04, conf_loss: 111.22, prob_loss:   1.66, total_loss: 113.91
# epoch: 4 step:   30/60, lr:0.000082, giou_loss:   1.07, conf_loss: 110.34, prob_loss:   3.26, total_loss: 114.67
# epoch: 4 step:   31/60, lr:0.000082, giou_loss:   1.09, conf_loss: 110.63, prob_loss:   1.58, total_loss: 113.31
# epoch: 4 step:   32/60, lr:0.000082, giou_loss:   1.42, conf_loss: 112.23, prob_loss:   2.94, total_loss: 116.58
# epoch: 4 step:   33/60, lr:0.000081, giou_loss:   1.33, conf_loss: 110.01, prob_loss:   1.35, total_loss: 112.69
# epoch: 4 step:   34/60, lr:0.000081, giou_loss:   1.16, conf_loss: 108.67, prob_loss:   1.01, total_loss: 110.83
# epoch: 4 step:   35/60, lr:0.000081, giou_loss:   1.15, conf_loss: 107.06, prob_loss:   2.11, total_loss: 110.32
# epoch: 4 step:   36/60, lr:0.000081, giou_loss:   1.00, conf_loss: 107.63, prob_loss:   1.80, total_loss: 110.43
# epoch: 4 step:   37/60, lr:0.000081, giou_loss:   2.17, conf_loss: 107.31, prob_loss:   4.36, total_loss: 113.84
# epoch: 4 step:   38/60, lr:0.000080, giou_loss:   1.41, conf_loss: 106.18, prob_loss:   2.80, total_loss: 110.39
# epoch: 4 step:   39/60, lr:0.000080, giou_loss:   0.83, conf_loss: 106.24, prob_loss:   3.78, total_loss: 110.84
# epoch: 4 step:   40/60, lr:0.000080, giou_loss:   1.56, conf_loss: 104.36, prob_loss:   2.95, total_loss: 108.87
# epoch: 4 step:   41/60, lr:0.000080, giou_loss:   1.07, conf_loss: 103.57, prob_loss:   2.02, total_loss: 106.67
# epoch: 4 step:   42/60, lr:0.000079, giou_loss:   1.00, conf_loss: 103.24, prob_loss:   3.51, total_loss: 107.76
# epoch: 4 step:   43/60, lr:0.000079, giou_loss:   1.77, conf_loss: 104.70, prob_loss:   3.25, total_loss: 109.71
# epoch: 4 step:   44/60, lr:0.000079, giou_loss:   0.98, conf_loss: 102.88, prob_loss:   4.40, total_loss: 108.26
# epoch: 4 step:   45/60, lr:0.000079, giou_loss:   1.97, conf_loss: 102.05, prob_loss:   3.45, total_loss: 107.47
# epoch: 4 step:   46/60, lr:0.000078, giou_loss:   1.03, conf_loss: 102.47, prob_loss:   1.49, total_loss: 105.00
# epoch: 4 step:   47/60, lr:0.000078, giou_loss:   0.97, conf_loss: 101.92, prob_loss:   3.43, total_loss: 106.32
# epoch: 4 step:   48/60, lr:0.000078, giou_loss:   0.88, conf_loss:  99.12, prob_loss:   1.65, total_loss: 101.65
# epoch: 4 step:   49/60, lr:0.000078, giou_loss:   1.71, conf_loss: 100.10, prob_loss:   1.43, total_loss: 103.23
# epoch: 4 step:   50/60, lr:0.000077, giou_loss:   1.11, conf_loss:  98.90, prob_loss:   1.78, total_loss: 101.79
# epoch: 4 step:   51/60, lr:0.000077, giou_loss:   1.41, conf_loss:  97.92, prob_loss:   3.07, total_loss: 102.40
# epoch: 4 step:   52/60, lr:0.000077, giou_loss:   1.83, conf_loss:  97.36, prob_loss:   3.73, total_loss: 102.92
# epoch: 4 step:   53/60, lr:0.000077, giou_loss:   1.15, conf_loss:  97.66, prob_loss:   2.92, total_loss: 101.73
# epoch: 4 step:   54/60, lr:0.000077, giou_loss:   2.00, conf_loss:  99.58, prob_loss:   4.90, total_loss: 106.49
# epoch: 4 step:   55/60, lr:0.000076, giou_loss:   1.39, conf_loss:  97.36, prob_loss:   2.24, total_loss: 100.99
# epoch: 4 step:   56/60, lr:0.000076, giou_loss:   1.43, conf_loss:  98.52, prob_loss:   2.53, total_loss: 102.48
# epoch: 4 step:   57/60, lr:0.000076, giou_loss:   0.96, conf_loss:  95.39, prob_loss:   1.31, total_loss:  97.66
# epoch: 4 step:   58/60, lr:0.000076, giou_loss:   0.86, conf_loss:  93.76, prob_loss:   0.67, total_loss:  95.29
# epoch: 4 step:   59/60, lr:0.000075, giou_loss:   0.82, conf_loss:  94.27, prob_loss:   1.19, total_loss:  96.28
# epoch: 4 step:    0/60, lr:0.000075, giou_loss:   1.28, conf_loss:  94.66, prob_loss:   3.64, total_loss:  99.58
# epoch: 4 step:    1/60, lr:0.000075, giou_loss:   0.94, conf_loss:  94.39, prob_loss:   1.71, total_loss:  97.04
#
#
# giou_val_loss:   1.65, conf_val_loss: 244.74, prob_val_loss:   4.33, total_val_loss: 250.72
#
#
# epoch: 5 step:    2/60, lr:0.000075, giou_loss:   1.07, conf_loss:  93.09, prob_loss:   2.12, total_loss:  96.28
# epoch: 5 step:    3/60, lr:0.000074, giou_loss:   1.17, conf_loss:  92.71, prob_loss:   2.18, total_loss:  96.06
# epoch: 5 step:    4/60, lr:0.000074, giou_loss:   1.89, conf_loss:  91.76, prob_loss:   1.76, total_loss:  95.41
# epoch: 5 step:    5/60, lr:0.000074, giou_loss:   1.27, conf_loss:  90.56, prob_loss:   1.04, total_loss:  92.88
# epoch: 5 step:    6/60, lr:0.000074, giou_loss:   1.09, conf_loss:  92.12, prob_loss:   1.73, total_loss:  94.93
# epoch: 5 step:    7/60, lr:0.000073, giou_loss:   0.91, conf_loss:  90.48, prob_loss:   1.59, total_loss:  92.98
# epoch: 5 step:    8/60, lr:0.000073, giou_loss:   1.03, conf_loss:  90.01, prob_loss:   1.89, total_loss:  92.92
# epoch: 5 step:    9/60, lr:0.000073, giou_loss:   1.09, conf_loss:  88.33, prob_loss:   5.25, total_loss:  94.67
# epoch: 5 step:   10/60, lr:0.000072, giou_loss:   0.78, conf_loss:  89.07, prob_loss:   0.55, total_loss:  90.40
# epoch: 5 step:   11/60, lr:0.000072, giou_loss:   1.24, conf_loss:  88.72, prob_loss:   1.41, total_loss:  91.38
# epoch: 5 step:   12/60, lr:0.000072, giou_loss:   0.98, conf_loss:  87.32, prob_loss:   0.89, total_loss:  89.18
# epoch: 5 step:   13/60, lr:0.000072, giou_loss:   1.06, conf_loss:  87.58, prob_loss:   1.81, total_loss:  90.46
# epoch: 5 step:   14/60, lr:0.000071, giou_loss:   1.25, conf_loss:  87.60, prob_loss:   1.16, total_loss:  90.01
# epoch: 5 step:   15/60, lr:0.000071, giou_loss:   0.85, conf_loss:  86.99, prob_loss:   3.40, total_loss:  91.24
# epoch: 5 step:   16/60, lr:0.000071, giou_loss:   1.33, conf_loss:  87.34, prob_loss:   2.50, total_loss:  91.17
# epoch: 5 step:   17/60, lr:0.000071, giou_loss:   1.38, conf_loss:  86.21, prob_loss:   5.29, total_loss:  92.88
# epoch: 5 step:   18/60, lr:0.000070, giou_loss:   1.10, conf_loss:  87.25, prob_loss:   2.90, total_loss:  91.25
# epoch: 5 step:   19/60, lr:0.000070, giou_loss:   0.98, conf_loss:  84.52, prob_loss:   2.37, total_loss:  87.87
# epoch: 5 step:   20/60, lr:0.000070, giou_loss:   1.12, conf_loss:  85.15, prob_loss:   3.45, total_loss:  89.71
# epoch: 5 step:   21/60, lr:0.000070, giou_loss:   1.38, conf_loss:  84.13, prob_loss:   3.23, total_loss:  88.74
# epoch: 5 step:   22/60, lr:0.000069, giou_loss:   1.14, conf_loss:  84.21, prob_loss:   2.54, total_loss:  87.88
# epoch: 5 step:   23/60, lr:0.000069, giou_loss:   1.82, conf_loss:  85.34, prob_loss:   2.34, total_loss:  89.50
# epoch: 5 step:   24/60, lr:0.000069, giou_loss:   0.66, conf_loss:  82.85, prob_loss:   1.57, total_loss:  85.09
# epoch: 5 step:   25/60, lr:0.000068, giou_loss:   0.75, conf_loss:  82.57, prob_loss:   3.17, total_loss:  86.48
# epoch: 5 step:   26/60, lr:0.000068, giou_loss:   1.27, conf_loss:  82.77, prob_loss:   3.36, total_loss:  87.40
# epoch: 5 step:   27/60, lr:0.000068, giou_loss:   1.25, conf_loss:  81.95, prob_loss:   1.97, total_loss:  85.17
# epoch: 5 step:   28/60, lr:0.000068, giou_loss:   1.30, conf_loss:  82.16, prob_loss:   2.96, total_loss:  86.42
# epoch: 5 step:   29/60, lr:0.000067, giou_loss:   1.35, conf_loss:  81.28, prob_loss:   2.33, total_loss:  84.96
# epoch: 5 step:   30/60, lr:0.000067, giou_loss:   1.36, conf_loss:  82.08, prob_loss:   1.91, total_loss:  85.35
# epoch: 5 step:   31/60, lr:0.000067, giou_loss:   1.39, conf_loss:  81.82, prob_loss:   2.78, total_loss:  85.99
# epoch: 5 step:   32/60, lr:0.000067, giou_loss:   1.02, conf_loss:  80.69, prob_loss:   2.25, total_loss:  83.96
# epoch: 5 step:   33/60, lr:0.000066, giou_loss:   1.20, conf_loss:  79.95, prob_loss:   2.80, total_loss:  83.94
# epoch: 5 step:   34/60, lr:0.000066, giou_loss:   1.65, conf_loss:  80.72, prob_loss:   2.59, total_loss:  84.96
# epoch: 5 step:   35/60, lr:0.000066, giou_loss:   1.04, conf_loss:  79.87, prob_loss:   1.90, total_loss:  82.82
# epoch: 5 step:   36/60, lr:0.000065, giou_loss:   1.14, conf_loss:  79.54, prob_loss:   2.39, total_loss:  83.08
# epoch: 5 step:   37/60, lr:0.000065, giou_loss:   1.27, conf_loss:  79.51, prob_loss:   3.99, total_loss:  84.77
# epoch: 5 step:   38/60, lr:0.000065, giou_loss:   0.94, conf_loss:  78.15, prob_loss:   1.39, total_loss:  80.48
# epoch: 5 step:   39/60, lr:0.000065, giou_loss:   1.05, conf_loss:  78.23, prob_loss:   2.02, total_loss:  81.31
# epoch: 5 step:   40/60, lr:0.000064, giou_loss:   0.67, conf_loss:  76.91, prob_loss:   1.34, total_loss:  78.91
# epoch: 5 step:   41/60, lr:0.000064, giou_loss:   0.83, conf_loss:  77.52, prob_loss:   3.33, total_loss:  81.68
# epoch: 5 step:   42/60, lr:0.000064, giou_loss:   1.86, conf_loss:  77.60, prob_loss:   3.11, total_loss:  82.57
# epoch: 5 step:   43/60, lr:0.000064, giou_loss:   0.74, conf_loss:  76.77, prob_loss:   0.69, total_loss:  78.20
# epoch: 5 step:   44/60, lr:0.000063, giou_loss:   1.50, conf_loss:  77.34, prob_loss:   1.98, total_loss:  80.82
# epoch: 5 step:   45/60, lr:0.000063, giou_loss:   0.86, conf_loss:  75.30, prob_loss:   0.64, total_loss:  76.81
# epoch: 5 step:   46/60, lr:0.000063, giou_loss:   1.05, conf_loss:  75.60, prob_loss:   0.74, total_loss:  77.39
# epoch: 5 step:   47/60, lr:0.000062, giou_loss:   1.59, conf_loss:  76.59, prob_loss:   2.30, total_loss:  80.48
# epoch: 5 step:   48/60, lr:0.000062, giou_loss:   0.63, conf_loss:  74.79, prob_loss:   0.54, total_loss:  75.97
# epoch: 5 step:   49/60, lr:0.000062, giou_loss:   1.46, conf_loss:  75.05, prob_loss:   2.26, total_loss:  78.77
# epoch: 5 step:   50/60, lr:0.000062, giou_loss:   1.76, conf_loss:  75.51, prob_loss:   3.13, total_loss:  80.39
# epoch: 5 step:   51/60, lr:0.000061, giou_loss:   1.08, conf_loss:  75.08, prob_loss:   3.78, total_loss:  79.94
# epoch: 5 step:   52/60, lr:0.000061, giou_loss:   1.17, conf_loss:  74.04, prob_loss:   1.13, total_loss:  76.34
# epoch: 5 step:   53/60, lr:0.000061, giou_loss:   0.89, conf_loss:  72.99, prob_loss:   3.92, total_loss:  77.80
# epoch: 5 step:   54/60, lr:0.000060, giou_loss:   1.03, conf_loss:  73.45, prob_loss:   3.80, total_loss:  78.27
# epoch: 5 step:   55/60, lr:0.000060, giou_loss:   2.35, conf_loss:  76.48, prob_loss:   4.04, total_loss:  82.88
# epoch: 5 step:   56/60, lr:0.000060, giou_loss:   0.89, conf_loss:  73.65, prob_loss:   1.85, total_loss:  76.40
# epoch: 5 step:   57/60, lr:0.000060, giou_loss:   1.11, conf_loss:  73.86, prob_loss:   1.79, total_loss:  76.76
# epoch: 5 step:   58/60, lr:0.000059, giou_loss:   1.53, conf_loss:  75.54, prob_loss:   3.27, total_loss:  80.34
# epoch: 5 step:   59/60, lr:0.000059, giou_loss:   1.34, conf_loss:  72.65, prob_loss:   0.88, total_loss:  74.87
# epoch: 5 step:    0/60, lr:0.000059, giou_loss:   1.63, conf_loss:  73.66, prob_loss:   1.88, total_loss:  77.18
# epoch: 5 step:    1/60, lr:0.000058, giou_loss:   1.40, conf_loss:  72.31, prob_loss:   3.22, total_loss:  76.93
#
#
# giou_val_loss:   1.66, conf_val_loss: 140.56, prob_val_loss:   4.41, total_val_loss: 146.63
#
#
# epoch: 6 step:    2/60, lr:0.000058, giou_loss:   1.26, conf_loss:  71.32, prob_loss:   3.34, total_loss:  75.92
# epoch: 6 step:    3/60, lr:0.000058, giou_loss:   0.94, conf_loss:  70.89, prob_loss:   0.57, total_loss:  72.41
# epoch: 6 step:    4/60, lr:0.000058, giou_loss:   1.01, conf_loss:  71.55, prob_loss:   1.64, total_loss:  74.19
# epoch: 6 step:    5/60, lr:0.000057, giou_loss:   1.10, conf_loss:  71.10, prob_loss:   2.11, total_loss:  74.30
# epoch: 6 step:    6/60, lr:0.000057, giou_loss:   1.16, conf_loss:  69.78, prob_loss:   2.16, total_loss:  73.10
# epoch: 6 step:    7/60, lr:0.000057, giou_loss:   1.23, conf_loss:  70.08, prob_loss:   1.38, total_loss:  72.68
# epoch: 6 step:    8/60, lr:0.000056, giou_loss:   0.89, conf_loss:  70.31, prob_loss:   0.84, total_loss:  72.04
# epoch: 6 step:    9/60, lr:0.000056, giou_loss:   2.90, conf_loss:  71.75, prob_loss:   2.99, total_loss:  77.64
# epoch: 6 step:   10/60, lr:0.000056, giou_loss:   0.98, conf_loss:  69.87, prob_loss:   1.75, total_loss:  72.60
# epoch: 6 step:   11/60, lr:0.000056, giou_loss:   1.11, conf_loss:  70.19, prob_loss:   1.83, total_loss:  73.13
# epoch: 6 step:   12/60, lr:0.000055, giou_loss:   1.02, conf_loss:  69.09, prob_loss:   1.95, total_loss:  72.06
# epoch: 6 step:   13/60, lr:0.000055, giou_loss:   1.23, conf_loss:  69.19, prob_loss:   2.46, total_loss:  72.88
# epoch: 6 step:   14/60, lr:0.000055, giou_loss:   1.25, conf_loss:  69.12, prob_loss:   0.66, total_loss:  71.02
# epoch: 6 step:   15/60, lr:0.000054, giou_loss:   0.89, conf_loss:  68.90, prob_loss:   2.30, total_loss:  72.09
# epoch: 6 step:   16/60, lr:0.000054, giou_loss:   0.90, conf_loss:  68.09, prob_loss:   1.46, total_loss:  70.45
# epoch: 6 step:   17/60, lr:0.000054, giou_loss:   1.25, conf_loss:  68.56, prob_loss:   3.89, total_loss:  73.70
# epoch: 6 step:   18/60, lr:0.000054, giou_loss:   1.06, conf_loss:  68.09, prob_loss:   2.40, total_loss:  71.54
# epoch: 6 step:   19/60, lr:0.000053, giou_loss:   1.04, conf_loss:  67.96, prob_loss:   2.63, total_loss:  71.63
# epoch: 6 step:   20/60, lr:0.000053, giou_loss:   1.61, conf_loss:  69.05, prob_loss:   4.38, total_loss:  75.04
# epoch: 6 step:   21/60, lr:0.000053, giou_loss:   1.59, conf_loss:  67.15, prob_loss:   2.22, total_loss:  70.96
# epoch: 6 step:   22/60, lr:0.000052, giou_loss:   1.22, conf_loss:  68.69, prob_loss:   2.31, total_loss:  72.22
# epoch: 6 step:   23/60, lr:0.000052, giou_loss:   1.93, conf_loss:  68.35, prob_loss:   5.12, total_loss:  75.40
# epoch: 6 step:   24/60, lr:0.000052, giou_loss:   1.07, conf_loss:  66.22, prob_loss:   0.85, total_loss:  68.13
# epoch: 6 step:   25/60, lr:0.000052, giou_loss:   0.87, conf_loss:  67.06, prob_loss:   1.66, total_loss:  69.58
# epoch: 6 step:   26/60, lr:0.000051, giou_loss:   1.19, conf_loss:  67.06, prob_loss:   2.33, total_loss:  70.58
# epoch: 6 step:   27/60, lr:0.000051, giou_loss:   1.27, conf_loss:  66.01, prob_loss:   1.02, total_loss:  68.29
# epoch: 6 step:   28/60, lr:0.000051, giou_loss:   1.04, conf_loss:  65.67, prob_loss:   2.39, total_loss:  69.10
# epoch: 6 step:   29/60, lr:0.000050, giou_loss:   1.00, conf_loss:  65.75, prob_loss:   0.84, total_loss:  67.60
# epoch: 6 step:   30/60, lr:0.000050, giou_loss:   0.71, conf_loss:  65.09, prob_loss:   0.59, total_loss:  66.38
# epoch: 6 step:   31/60, lr:0.000050, giou_loss:   0.55, conf_loss:  65.17, prob_loss:   1.70, total_loss:  67.42
# epoch: 6 step:   32/60, lr:0.000049, giou_loss:   1.63, conf_loss:  65.45, prob_loss:   3.79, total_loss:  70.87
# epoch: 6 step:   33/60, lr:0.000049, giou_loss:   0.75, conf_loss:  64.98, prob_loss:   2.21, total_loss:  67.95
# epoch: 6 step:   34/60, lr:0.000049, giou_loss:   1.09, conf_loss:  64.58, prob_loss:   4.33, total_loss:  70.00
# epoch: 6 step:   35/60, lr:0.000049, giou_loss:   1.76, conf_loss:  64.64, prob_loss:   1.38, total_loss:  67.78
# epoch: 6 step:   36/60, lr:0.000048, giou_loss:   1.18, conf_loss:  66.75, prob_loss:   1.54, total_loss:  69.48
# epoch: 6 step:   37/60, lr:0.000048, giou_loss:   0.75, conf_loss:  64.20, prob_loss:   1.02, total_loss:  65.96
# epoch: 6 step:   38/60, lr:0.000048, giou_loss:   1.87, conf_loss:  64.85, prob_loss:   3.08, total_loss:  69.80
# epoch: 6 step:   39/60, lr:0.000047, giou_loss:   1.70, conf_loss:  65.14, prob_loss:   2.88, total_loss:  69.72
# epoch: 6 step:   40/60, lr:0.000047, giou_loss:   1.44, conf_loss:  63.89, prob_loss:   2.10, total_loss:  67.43
# epoch: 6 step:   41/60, lr:0.000047, giou_loss:   1.18, conf_loss:  63.98, prob_loss:   1.53, total_loss:  66.69
# epoch: 6 step:   42/60, lr:0.000047, giou_loss:   0.91, conf_loss:  62.90, prob_loss:   1.76, total_loss:  65.57
# epoch: 6 step:   43/60, lr:0.000046, giou_loss:   0.89, conf_loss:  63.17, prob_loss:   1.78, total_loss:  65.84
# epoch: 6 step:   44/60, lr:0.000046, giou_loss:   1.47, conf_loss:  63.29, prob_loss:   1.04, total_loss:  65.79
# epoch: 6 step:   45/60, lr:0.000046, giou_loss:   0.92, conf_loss:  62.01, prob_loss:   0.93, total_loss:  63.85
# epoch: 6 step:   46/60, lr:0.000045, giou_loss:   0.97, conf_loss:  61.77, prob_loss:   1.51, total_loss:  64.25
# epoch: 6 step:   47/60, lr:0.000045, giou_loss:   1.15, conf_loss:  61.47, prob_loss:   1.17, total_loss:  63.79
# epoch: 6 step:   48/60, lr:0.000045, giou_loss:   0.88, conf_loss:  61.76, prob_loss:   0.41, total_loss:  63.06
# epoch: 6 step:   49/60, lr:0.000045, giou_loss:   1.57, conf_loss:  62.74, prob_loss:   2.85, total_loss:  67.16
# epoch: 6 step:   50/60, lr:0.000044, giou_loss:   1.12, conf_loss:  62.83, prob_loss:   2.18, total_loss:  66.13
# epoch: 6 step:   51/60, lr:0.000044, giou_loss:   0.74, conf_loss:  61.63, prob_loss:   2.40, total_loss:  64.77
# epoch: 6 step:   52/60, lr:0.000044, giou_loss:   0.56, conf_loss:  61.62, prob_loss:   0.97, total_loss:  63.15
# epoch: 6 step:   53/60, lr:0.000043, giou_loss:   1.06, conf_loss:  62.26, prob_loss:   2.14, total_loss:  65.46
# epoch: 6 step:   54/60, lr:0.000043, giou_loss:   1.11, conf_loss:  61.06, prob_loss:   1.60, total_loss:  63.77
# epoch: 6 step:   55/60, lr:0.000043, giou_loss:   1.14, conf_loss:  61.72, prob_loss:   2.17, total_loss:  65.03
# epoch: 6 step:   56/60, lr:0.000043, giou_loss:   0.98, conf_loss:  60.22, prob_loss:   3.80, total_loss:  65.00
# ...
# epoch: 8 step:   43/60, lr:0.000015, giou_loss:   1.23, conf_loss:  51.95, prob_loss:   5.50, total_loss:  58.68
# epoch: 8 step:   44/60, lr:0.000015, giou_loss:   1.43, conf_loss:  53.69, prob_loss:   2.46, total_loss:  57.58
# epoch: 8 step:   45/60, lr:0.000015, giou_loss:   0.99, conf_loss:  51.55, prob_loss:   0.54, total_loss:  53.07
# epoch: 8 step:   46/60, lr:0.000015, giou_loss:   0.76, conf_loss:  51.09, prob_loss:   0.49, total_loss:  52.34
# epoch: 8 step:   47/60, lr:0.000014, giou_loss:   1.83, conf_loss:  52.72, prob_loss:   3.22, total_loss:  57.77
# epoch: 8 step:   48/60, lr:0.000014, giou_loss:   0.73, conf_loss:  51.23, prob_loss:   0.76, total_loss:  52.72
# epoch: 8 step:   49/60, lr:0.000014, giou_loss:   0.68, conf_loss:  51.22, prob_loss:   0.72, total_loss:  52.62
# epoch: 8 step:   50/60, lr:0.000014, giou_loss:   1.68, conf_loss:  53.07, prob_loss:   1.96, total_loss:  56.71
# epoch: 8 step:   51/60, lr:0.000014, giou_loss:   0.81, conf_loss:  51.37, prob_loss:   1.82, total_loss:  54.00
# epoch: 8 step:   52/60, lr:0.000013, giou_loss:   1.08, conf_loss:  50.66, prob_loss:   3.51, total_loss:  55.24
# epoch: 8 step:   53/60, lr:0.000013, giou_loss:   0.80, conf_loss:  50.43, prob_loss:   0.41, total_loss:  51.64
# epoch: 8 step:   54/60, lr:0.000013, giou_loss:   1.02, conf_loss:  50.75, prob_loss:   1.47, total_loss:  53.25
# epoch: 8 step:   55/60, lr:0.000013, giou_loss:   0.77, conf_loss:  51.57, prob_loss:   1.36, total_loss:  53.70
# epoch: 8 step:   56/60, lr:0.000013, giou_loss:   0.46, conf_loss:  50.80, prob_loss:   1.12, total_loss:  52.39
# epoch: 8 step:   57/60, lr:0.000012, giou_loss:   0.64, conf_loss:  50.29, prob_loss:   3.78, total_loss:  54.71
# epoch: 8 step:   58/60, lr:0.000012, giou_loss:   1.34, conf_loss:  51.60, prob_loss:   2.36, total_loss:  55.30
# epoch: 8 step:   59/60, lr:0.000012, giou_loss:   0.91, conf_loss:  50.50, prob_loss:   0.64, total_loss:  52.06
# epoch: 8 step:    0/60, lr:0.000012, giou_loss:   1.54, conf_loss:  51.30, prob_loss:   2.25, total_loss:  55.08
# epoch: 8 step:    1/60, lr:0.000012, giou_loss:   0.57, conf_loss:  50.38, prob_loss:   0.56, total_loss:  51.51
#
#
# giou_val_loss:   1.33, conf_val_loss:  69.78, prob_val_loss:   4.40, total_val_loss:  75.51
#
#
# epoch: 9 step:    2/60, lr:0.000011, giou_loss:   1.23, conf_loss:  50.58, prob_loss:   1.12, total_loss:  52.93
# epoch: 9 step:    3/60, lr:0.000011, giou_loss:   0.73, conf_loss:  50.10, prob_loss:   0.63, total_loss:  51.46
# epoch: 9 step:    4/60, lr:0.000011, giou_loss:   1.46, conf_loss:  53.19, prob_loss:   2.82, total_loss:  57.47
# epoch: 9 step:    5/60, lr:0.000011, giou_loss:   1.03, conf_loss:  51.80, prob_loss:   2.90, total_loss:  55.73
# epoch: 9 step:    6/60, lr:0.000011, giou_loss:   1.06, conf_loss:  51.27, prob_loss:   3.59, total_loss:  55.92
# epoch: 9 step:    7/60, lr:0.000011, giou_loss:   0.68, conf_loss:  50.73, prob_loss:   0.81, total_loss:  52.22
# epoch: 9 step:    8/60, lr:0.000010, giou_loss:   0.92, conf_loss:  50.50, prob_loss:   3.24, total_loss:  54.66
# epoch: 9 step:    9/60, lr:0.000010, giou_loss:   0.95, conf_loss:  49.61, prob_loss:   0.50, total_loss:  51.07
# epoch: 9 step:   10/60, lr:0.000010, giou_loss:   0.81, conf_loss:  50.08, prob_loss:   1.02, total_loss:  51.91
# epoch: 9 step:   11/60, lr:0.000010, giou_loss:   0.72, conf_loss:  50.38, prob_loss:   0.76, total_loss:  51.86
# epoch: 9 step:   12/60, lr:0.000010, giou_loss:   0.93, conf_loss:  50.08, prob_loss:   0.53, total_loss:  51.54
# epoch: 9 step:   13/60, lr:0.000009, giou_loss:   0.90, conf_loss:  49.98, prob_loss:   0.63, total_loss:  51.51
# epoch: 9 step:   14/60, lr:0.000009, giou_loss:   1.53, conf_loss:  50.64, prob_loss:   4.66, total_loss:  56.83
# epoch: 9 step:   15/60, lr:0.000009, giou_loss:   1.53, conf_loss:  51.21, prob_loss:   3.23, total_loss:  55.97
# epoch: 9 step:   16/60, lr:0.000009, giou_loss:   0.57, conf_loss:  58.55, prob_loss:   0.47, total_loss:  59.59
# epoch: 9 step:   17/60, lr:0.000009, giou_loss:   1.16, conf_loss:  50.57, prob_loss:   3.02, total_loss:  54.76
# epoch: 9 step:   18/60, lr:0.000009, giou_loss:   1.44, conf_loss:  49.73, prob_loss:   1.05, total_loss:  52.22
# epoch: 9 step:   19/60, lr:0.000008, giou_loss:   0.68, conf_loss:  49.96, prob_loss:   1.39, total_loss:  52.03
# epoch: 9 step:   20/60, lr:0.000008, giou_loss:   1.06, conf_loss:  50.69, prob_loss:   1.94, total_loss:  53.69
# epoch: 9 step:   21/60, lr:0.000008, giou_loss:   1.06, conf_loss:  50.10, prob_loss:   0.99, total_loss:  52.15
# epoch: 9 step:   22/60, lr:0.000008, giou_loss:   1.06, conf_loss:  50.93, prob_loss:   1.47, total_loss:  53.47
# epoch: 9 step:   23/60, lr:0.000008, giou_loss:   0.69, conf_loss:  49.49, prob_loss:   0.38, total_loss:  50.55
# epoch: 9 step:   24/60, lr:0.000008, giou_loss:   1.25, conf_loss:  50.98, prob_loss:   2.69, total_loss:  54.92
# epoch: 9 step:   25/60, lr:0.000008, giou_loss:   1.13, conf_loss:  50.10, prob_loss:   1.27, total_loss:  52.49
# epoch: 9 step:   26/60, lr:0.000007, giou_loss:   0.72, conf_loss:  49.58, prob_loss:   2.55, total_loss:  52.85
# epoch: 9 step:   27/60, lr:0.000007, giou_loss:   0.95, conf_loss:  50.99, prob_loss:   1.40, total_loss:  53.33
# epoch: 9 step:   28/60, lr:0.000007, giou_loss:   1.08, conf_loss:  50.77, prob_loss:   2.14, total_loss:  54.00
# epoch: 9 step:   29/60, lr:0.000007, giou_loss:   1.25, conf_loss:  51.21, prob_loss:   2.87, total_loss:  55.33
# epoch: 9 step:   30/60, lr:0.000007, giou_loss:   0.83, conf_loss:  50.29, prob_loss:   1.02, total_loss:  52.15
# epoch: 9 step:   31/60, lr:0.000007, giou_loss:   0.83, conf_loss:  50.61, prob_loss:   2.83, total_loss:  54.27
# epoch: 9 step:   32/60, lr:0.000007, giou_loss:   0.78, conf_loss:  49.86, prob_loss:   0.50, total_loss:  51.15
# epoch: 9 step:   33/60, lr:0.000006, giou_loss:   0.86, conf_loss:  49.72, prob_loss:   2.40, total_loss:  52.98
# epoch: 9 step:   34/60, lr:0.000006, giou_loss:   0.79, conf_loss:  50.11, prob_loss:   0.61, total_loss:  51.52
# epoch: 9 step:   35/60, lr:0.000006, giou_loss:   0.72, conf_loss:  49.62, prob_loss:   0.93, total_loss:  51.28
# epoch: 9 step:   36/60, lr:0.000006, giou_loss:   1.32, conf_loss:  51.35, prob_loss:   2.62, total_loss:  55.29
# epoch: 9 step:   37/60, lr:0.000006, giou_loss:   0.94, conf_loss:  49.62, prob_loss:   1.06, total_loss:  51.61
# epoch: 9 step:   38/60, lr:0.000006, giou_loss:   1.22, conf_loss:  50.88, prob_loss:   1.84, total_loss:  53.93
# epoch: 9 step:   39/60, lr:0.000006, giou_loss:   1.10, conf_loss:  50.62, prob_loss:   2.70, total_loss:  54.42
# epoch: 9 step:   40/60, lr:0.000005, giou_loss:   0.64, conf_loss:  49.25, prob_loss:   1.02, total_loss:  50.90
# epoch: 9 step:   41/60, lr:0.000005, giou_loss:   0.73, conf_loss:  49.74, prob_loss:   0.54, total_loss:  51.00
# epoch: 9 step:   42/60, lr:0.000005, giou_loss:   1.19, conf_loss:  49.13, prob_loss:   2.45, total_loss:  52.77
# epoch: 9 step:   43/60, lr:0.000005, giou_loss:   0.88, conf_loss:  49.14, prob_loss:   0.92, total_loss:  50.94
# epoch: 9 step:   44/60, lr:0.000005, giou_loss:   0.94, conf_loss:  50.11, prob_loss:   2.96, total_loss:  54.01
# epoch: 9 step:   45/60, lr:0.000005, giou_loss:   0.89, conf_loss:  49.30, prob_loss:   3.39, total_loss:  53.57
# epoch: 9 step:   46/60, lr:0.000005, giou_loss:   0.69, conf_loss:  48.96, prob_loss:   0.52, total_loss:  50.17
# epoch: 9 step:   47/60, lr:0.000005, giou_loss:   0.68, conf_loss:  50.14, prob_loss:   0.98, total_loss:  51.80
# epoch: 9 step:   48/60, lr:0.000004, giou_loss:   0.73, conf_loss:  49.32, prob_loss:   1.55, total_loss:  51.60
# epoch: 9 step:   49/60, lr:0.000004, giou_loss:   0.76, conf_loss:  49.51, prob_loss:   1.02, total_loss:  51.30
# epoch: 9 step:   50/60, lr:0.000004, giou_loss:   1.09, conf_loss:  50.27, prob_loss:   2.97, total_loss:  54.33
# epoch: 9 step:   51/60, lr:0.000004, giou_loss:   0.81, conf_loss:  48.91, prob_loss:   0.80, total_loss:  50.52
# epoch: 9 step:   52/60, lr:0.000004, giou_loss:   1.15, conf_loss:  50.08, prob_loss:   1.25, total_loss:  52.48
# epoch: 9 step:   53/60, lr:0.000004, giou_loss:   1.00, conf_loss:  50.11, prob_loss:   1.95, total_loss:  53.06
# epoch: 9 step:   54/60, lr:0.000004, giou_loss:   1.36, conf_loss:  50.48, prob_loss:   2.97, total_loss:  54.81
# epoch: 9 step:   55/60, lr:0.000004, giou_loss:   0.65, conf_loss:  49.03, prob_loss:   0.31, total_loss:  49.99
# epoch: 9 step:   56/60, lr:0.000004, giou_loss:   1.15, conf_loss:  50.00, prob_loss:   1.94, total_loss:  53.09
# epoch: 9 step:   57/60, lr:0.000003, giou_loss:   1.29, conf_loss:  50.42, prob_loss:   1.10, total_loss:  52.82
# epoch: 9 step:   58/60, lr:0.000003, giou_loss:   1.13, conf_loss:  49.60, prob_loss:   1.01, total_loss:  51.74
# epoch: 9 step:   59/60, lr:0.000003, giou_loss:   0.75, conf_loss:  50.06, prob_loss:   1.24, total_loss:  52.05
# epoch: 9 step:    0/60, lr:0.000003, giou_loss:   0.89, conf_loss:  49.62, prob_loss:   0.90, total_loss:  51.41
# epoch: 9 step:    1/60, lr:0.000003, giou_loss:   0.94, conf_loss:  49.59, prob_loss:   1.92, total_loss:  52.45
#
#
# giou_val_loss:   1.15, conf_val_loss:  60.75, prob_val_loss:   2.68, total_val_loss:  64.58
#
#
# epoch:10 step:    2/60, lr:0.000003, giou_loss:   0.66, conf_loss:  49.35, prob_loss:   1.08, total_loss:  51.09
# epoch:10 step:    3/60, lr:0.000003, giou_loss:   1.18, conf_loss:  49.57, prob_loss:   1.62, total_loss:  52.36
# epoch:10 step:    4/60, lr:0.000003, giou_loss:   0.61, conf_loss:  49.15, prob_loss:   1.15, total_loss:  50.91
# epoch:10 step:    5/60, lr:0.000003, giou_loss:   0.69, conf_loss:  50.25, prob_loss:   1.20, total_loss:  52.14
# epoch:10 step:    6/60, lr:0.000003, giou_loss:   0.87, conf_loss:  49.15, prob_loss:   0.51, total_loss:  50.52
# epoch:10 step:    7/60, lr:0.000002, giou_loss:   0.74, conf_loss:  49.13, prob_loss:   0.33, total_loss:  50.20
# epoch:10 step:    8/60, lr:0.000002, giou_loss:   1.04, conf_loss:  49.62, prob_loss:   1.01, total_loss:  51.67
# epoch:10 step:    9/60, lr:0.000002, giou_loss:   0.86, conf_loss:  49.52, prob_loss:   3.42, total_loss:  53.80
# epoch:10 step:   10/60, lr:0.000002, giou_loss:   1.15, conf_loss:  49.88, prob_loss:   1.44, total_loss:  52.46
# epoch:10 step:   11/60, lr:0.000002, giou_loss:   1.24, conf_loss:  49.61, prob_loss:   1.32, total_loss:  52.16
# epoch:10 step:   12/60, lr:0.000002, giou_loss:   1.14, conf_loss:  50.34, prob_loss:   1.19, total_loss:  52.68
# epoch:10 step:   13/60, lr:0.000002, giou_loss:   1.25, conf_loss:  50.57, prob_loss:   1.21, total_loss:  53.02
# epoch:10 step:   14/60, lr:0.000002, giou_loss:   0.71, conf_loss:  48.97, prob_loss:   0.70, total_loss:  50.38
# epoch:10 step:   15/60, lr:0.000002, giou_loss:   0.47, conf_loss:  48.71, prob_loss:   0.78, total_loss:  49.95
# epoch:10 step:   16/60, lr:0.000002, giou_loss:   0.61, conf_loss:  48.73, prob_loss:   0.51, total_loss:  49.84
# epoch:10 step:   17/60, lr:0.000002, giou_loss:   1.15, conf_loss:  49.73, prob_loss:   1.71, total_loss:  52.59
# epoch:10 step:   18/60, lr:0.000002, giou_loss:   0.65, conf_loss:  48.50, prob_loss:   0.83, total_loss:  49.98
# epoch:10 step:   19/60, lr:0.000002, giou_loss:   0.66, conf_loss:  48.60, prob_loss:   3.46, total_loss:  52.71
# epoch:10 step:   20/60, lr:0.000001, giou_loss:   1.08, conf_loss:  49.00, prob_loss:   0.81, total_loss:  50.89
# epoch:10 step:   21/60, lr:0.000001, giou_loss:   1.17, conf_loss:  49.48, prob_loss:   1.92, total_loss:  52.57
# epoch:10 step:   22/60, lr:0.000001, giou_loss:   1.35, conf_loss:  49.83, prob_loss:   2.10, total_loss:  53.27
# epoch:10 step:   23/60, lr:0.000001, giou_loss:   1.26, conf_loss:  50.18, prob_loss:   4.60, total_loss:  56.04
# epoch:10 step:   24/60, lr:0.000001, giou_loss:   1.01, conf_loss:  49.23, prob_loss:   0.58, total_loss:  50.83
# epoch:10 step:   25/60, lr:0.000001, giou_loss:   0.77, conf_loss:  48.64, prob_loss:   0.98, total_loss:  50.39
# epoch:10 step:   26/60, lr:0.000001, giou_loss:   1.43, conf_loss:  50.31, prob_loss:   2.35, total_loss:  54.09
# epoch:10 step:   27/60, lr:0.000001, giou_loss:   0.45, conf_loss:  48.51, prob_loss:   0.37, total_loss:  49.32
# epoch:10 step:   28/60, lr:0.000001, giou_loss:   0.44, conf_loss:  49.83, prob_loss:   1.03, total_loss:  51.30
# epoch:10 step:   29/60, lr:0.000001, giou_loss:   1.08, conf_loss:  49.44, prob_loss:   1.30, total_loss:  51.82
# epoch:10 step:   30/60, lr:0.000001, giou_loss:   0.96, conf_loss:  49.73, prob_loss:   1.91, total_loss:  52.61
# epoch:10 step:   31/60, lr:0.000001, giou_loss:   0.89, conf_loss:  49.55, prob_loss:   1.05, total_loss:  51.49
# epoch:10 step:   32/60, lr:0.000001, giou_loss:   0.60, conf_loss:  48.90, prob_loss:   0.38, total_loss:  49.87
# epoch:10 step:   33/60, lr:0.000001, giou_loss:   0.56, conf_loss:  48.56, prob_loss:   0.27, total_loss:  49.40
# epoch:10 step:   34/60, lr:0.000001, giou_loss:   0.82, conf_loss:  48.91, prob_loss:   0.76, total_loss:  50.49
# epoch:10 step:   35/60, lr:0.000001, giou_loss:   0.93, conf_loss:  49.93, prob_loss:   1.87, total_loss:  52.74
# epoch:10 step:   36/60, lr:0.000001, giou_loss:   0.57, conf_loss:  48.77, prob_loss:   0.81, total_loss:  50.15
# epoch:10 step:   37/60, lr:0.000001, giou_loss:   1.42, conf_loss:  51.04, prob_loss:   2.77, total_loss:  55.23
# epoch:10 step:   38/60, lr:0.000001, giou_loss:   0.78, conf_loss:  49.06, prob_loss:   0.58, total_loss:  50.42
# epoch:10 step:   39/60, lr:0.000000, giou_loss:   0.58, conf_loss:  49.01, prob_loss:   1.30, total_loss:  50.88
# epoch:10 step:   40/60, lr:0.000000, giou_loss:   1.58, conf_loss:  50.00, prob_loss:   1.72, total_loss:  53.30
# epoch:10 step:   41/60, lr:0.000000, giou_loss:   0.94, conf_loss:  48.75, prob_loss:   0.56, total_loss:  50.25
# epoch:10 step:   42/60, lr:0.000000, giou_loss:   0.82, conf_loss:  48.84, prob_loss:   0.66, total_loss:  50.32
# epoch:10 step:   43/60, lr:0.000000, giou_loss:   0.96, conf_loss:  49.01, prob_loss:   0.81, total_loss:  50.78
# epoch:10 step:   44/60, lr:0.000000, giou_loss:   0.76, conf_loss:  49.21, prob_loss:   0.61, total_loss:  50.58
# epoch:10 step:   45/60, lr:0.000000, giou_loss:   0.94, conf_loss:  50.13, prob_loss:   0.53, total_loss:  51.60
# epoch:10 step:   46/60, lr:0.000000, giou_loss:   0.77, conf_loss:  48.49, prob_loss:   0.46, total_loss:  49.72
# epoch:10 step:   47/60, lr:0.000000, giou_loss:   0.96, conf_loss:  49.65, prob_loss:   1.07, total_loss:  51.68
# epoch:10 step:   48/60, lr:0.000000, giou_loss:   1.04, conf_loss:  50.60, prob_loss:   3.15, total_loss:  54.79
# epoch:10 step:   49/60, lr:0.000000, giou_loss:   0.67, conf_loss:  48.70, prob_loss:   2.49, total_loss:  51.86
# epoch:10 step:   50/60, lr:0.000000, giou_loss:   1.01, conf_loss:  50.23, prob_loss:   1.33, total_loss:  52.57
# epoch:10 step:   51/60, lr:0.000000, giou_loss:   0.83, conf_loss:  49.26, prob_loss:   1.41, total_loss:  51.50
# epoch:10 step:   52/60, lr:0.000000, giou_loss:   0.92, conf_loss:  49.60, prob_loss:   1.90, total_loss:  52.42
# epoch:10 step:   53/60, lr:0.000000, giou_loss:   1.30, conf_loss:  50.55, prob_loss:   1.90, total_loss:  53.74
# epoch:10 step:   54/60, lr:0.000000, giou_loss:   1.13, conf_loss:  50.21, prob_loss:   1.16, total_loss:  52.50
# epoch:10 step:   55/60, lr:0.000000, giou_loss:   0.67, conf_loss:  49.11, prob_loss:   0.95, total_loss:  50.74
# epoch:10 step:   56/60, lr:0.000000, giou_loss:   1.40, conf_loss:  50.24, prob_loss:   1.22, total_loss:  52.86
# epoch:10 step:   57/60, lr:0.000000, giou_loss:   1.07, conf_loss:  50.09, prob_loss:   2.96, total_loss:  54.12
# epoch:10 step:   58/60, lr:0.000000, giou_loss:   1.01, conf_loss:  49.83, prob_loss:   2.10, total_loss:  52.93
# epoch:10 step:   59/60, lr:0.000000, giou_loss:   1.49, conf_loss:  50.46, prob_loss:   2.65, total_loss:  54.60
# epoch:10 step:    0/60, lr:0.000000, giou_loss:   0.69, conf_loss:  48.18, prob_loss:   0.80, total_loss:  49.68
# epoch:10 step:    1/60, lr:0.000000, giou_loss:   1.88, conf_loss:  52.05, prob_loss:   2.03, total_loss:  55.96
#
#
# giou_val_loss:   1.08, conf_val_loss:  55.68, prob_val_loss:   2.02, total_val_loss:  58.79

# %% [markdown]
# test

# %%
import os
import cv2
import numpy as np
import random
import time
import tensorflow as tf
from google.colab.patches import cv2_imshow


YOLO_INPUT_SIZE = 416
input_size=YOLO_INPUT_SIZE

ID = random.randint(0, 200)

image_path ="./fruits_data/fruits/test/mixed_23.jpg" #image_info[0]

yolo = Create_Yolov3(input_size=input_size, CLASSES=TRAIN_CLASSES)
yolo.load_weights("./checkpoints/yolov3_custom")



img = detect_image(yolo, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x1124 at 0x7FC42A62A590>

# %%
#yolo.save('saved_model/racoon_detection_model')

yolo.save("my_model.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
ls
# Out:
#  airplane.jpg                      pothole
#  checkpoints/                      project_video.mp4
#  fruits_data/                      racoon_data/
#  fruit_yolov3_training.ipynb       racoon_images/
#  inference.py                      racoon_test_images/
#  iou_giou_nms.ipynb                racoon_yolov3_training.ipynb
#  labelImg/                        ' selective_search.ipynb'
#  localization_randomcircle.ipynb  'simple_localization.ipynb의 사본'
#  model_data/                      'yolo_basic.ipynb의 사본'
#  my_model.h5

# %%
loaded_model = tf.keras.models.load_model('my_model.h5')

loaded_model.load_weights("./checkpoints/yolov3_custom")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
image_path ="test.JPG" 

img = detect_image(loaded_model, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-c7c38564638b> in <module>()
#       3 image_path ="test.JPG"
#       4
# ----> 5 img = detect_image(loaded_model, image_path, "", input_size=input_size, show=True, CLASSES=TRAIN_CLASSES, rectangle_colors=(255,0,0))
#       6 cv2_imshow(img)
#
# <ipython-input-13-808171fef485> in detect_image(YoloV3, image_path, output_path, input_size, show, CLASSES, score_threshold, iou_threshold, rectangle_colors)
#       2     original_image      = cv2.imread(image_path)
#       3
# ----> 4     original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
#       5     original_image      = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
#       6
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
