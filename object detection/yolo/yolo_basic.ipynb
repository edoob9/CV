# %% [markdown]
# <a href="https://colab.research.google.com/github/edenLee94/CV/blob/main/object%20detection/yolo/yolo_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython import display
from IPython.display import clear_output

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov3
# %cd yolov3
# %pip install -qr requirements.txt

import yaml
import torch

print(f"Torch: {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10029, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10029 (delta 3), reused 9 (delta 3), pack-reused 10017
# Receiving objects: 100% (10029/10029), 9.36 MiB | 23.60 MiB/s, done.
# Resolving deltas: 100% (6762/6762), done.
# /content/yolov3
#      |████████████████████████████████| 596 kB 5.4 MB/s
#      |████████████████████████████████| 1.8 MB 63.8 MB/s
#      |████████████████████████████████| 181 kB 57.7 MB/s
#      |████████████████████████████████| 146 kB 66.1 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
# Torch: 1.12.0+cu113 (Tesla T4)

# %%
# !pwd
# Out:
# /content/yolov3

# %% [markdown]
# 예시 확인하기

# %%
# !ls data/images
# Out:
# bus.jpg  zidane.jpg

# %%
Image(filename='data/images/bus.jpg', width=600)

# %%
Image(filename='data/images/zidane.jpg', width=600)

# %% [markdown]
# 미리 학습된 weight를 가지고 예시인 사진에 적용해서 확인하기

# %%
# !python detect.py --weights yolov3.pt --img 640 --conf 0.25 --source data/images/
# Out:
# ...
# detect: weights=['yolov3.pt'], source=data/images/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-21-g92c3bd7 torch 1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
# 100% 119M/119M [00:01<00:00, 82.9MB/s]
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, Done. (0.051s)
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.041s)
# Speed: 0.6ms pre-process, 46.1ms inference, 18.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
Image(filename='runs/detect/exp/bus.jpg', width=600)

# %%
Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %% [markdown]
# ## YOLO v5

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12580, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 12580 (delta 1), reused 4 (delta 1), pack-reused 12575
# Receiving objects: 100% (12580/12580), 12.32 MiB | 30.18 MiB/s, done.
# Resolving deltas: 100% (8656/8656), done.
# /content/yolov5
#      |████████████████████████████████| 750.6 MB 11 kB/s
#      |████████████████████████████████| 21.0 MB 1.4 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 0.12.0+cu113 requires torch==1.12.0, but you have torch 1.11.0 which is incompatible.

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
# Out:
# detect: weights=['yolov5s.pt'], source=data/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-295-gf8722b4 Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 136MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.011s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.010s)
# Speed: 0.6ms pre-process, 10.9ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
Image(filename='runs/detect/exp/bus.jpg', width=1000)

# %%
Image(filename='runs/detect/exp/zidane.jpg', width=1000)
